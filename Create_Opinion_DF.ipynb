# %%
from proxies import get_proxies, check_proxies
import pickle

# %%
working_proxies = check_proxies()
# Out:
# ip address : 14.99.235.174
# port : 80
# https : no
#
# ip address : 175.141.69.200
# port : 80
# https : no
#
# ip address : 14.99.235.171
# port : 80
# https : no
#
# ip address : 14.99.235.168
# port : 80
# https : no
#
# ip address : 193.56.255.133
# port : 3128
# https : yes
#
# ip address : 192.109.165.41
# port : 80
# https : no
#
# ip address : 1.10.189.156
# port : 32078
# https : no
#
# ip address : 135.181.41.222
# port : 80
# https : no
#
# ip address : 154.16.63.16
# port : 3128
# https : no
#
# ip address : 103.115.14.158
# port : 80
# https : no
#
# ip address : 118.27.1.112
# port : 3128
# https : yes
#
# ip address : 103.134.254.9
# port : 80
# https : no
#
# ip address : 52.74.18.115
# port : 80
# https : no
#
# ip address : 179.127.13.148
# port : 3128
# https : yes
#
# ip address : 89.187.177.102
# port : 80
# https : no
#
# ip address : 62.23.15.92
# port : 3128
# https : yes
#
# ip address : 103.115.14.41
# port : 80
# https : no
#
# ip address : 195.146.50.22
# port : 3128
# https : no
#
# ip address : 35.235.115.241
# port : 80
# https : no
#
# ip address : 8.129.28.247
# port : 8888
# https : no
#
# ip address : 88.198.50.103
# port : 8080
# https : no
#
# ip address : 181.30.60.148
# port : 8080
# https : yes
#
# ip address : 52.43.61.135
# port : 80
# https : no
#
# ip address : 104.248.48.161
# port : 31583
# https : no
#
# ip address : 176.9.75.42
# port : 8080
# https : no
#
# ip address : 159.203.61.169
# port : 3128
# https : no
#
# ip address : 178.134.155.82
# port : 48146
# https : yes
#
# ip address : 213.105.29.14
# port : 3128
# https : yes
#
# ip address : 41.65.174.66
# port : 8080
# https : yes
#
# ip address : 185.131.60.17
# port : 8080
# https : yes
#
# ip address : 83.103.193.74
# port : 13192
# https : yes
#
# ip address : 208.80.28.208
# port : 8080
# https : yes
#
# ip address : 89.187.177.97
# port : 80
# https : no
#
# ip address : 89.187.177.105
# port : 80
# https : no
#
# ip address : 89.187.177.93
# port : 80
# https : no
#
# ip address : 89.187.177.91
# port : 80
# https : no
#
# ip address : 89.187.177.107
# port : 80
# https : no
#
# ip address : 89.187.177.90
# port : 80
# https : no
#
# ip address : 64.225.65.250
# port : 80
# https : no
#
# ip address : 46.4.96.137
# port : 3128
# https : no
#
# ip address : 89.187.177.96
# port : 80
# https : no
#
# ip address : 192.227.108.83
# port : 80
# https : no
#
# ip address : 103.156.225.18
# port : 8080
# https : no
#
# ip address : 139.162.78.109
# port : 8080
# https : no
#
# ip address : 88.198.24.108
# port : 8080
# https : no
#
# ip address : 91.234.127.222
# port : 53281
# https : no
#
# ip address : 51.75.147.33
# port : 3128
# https : no
#
# ip address : 188.129.219.142
# port : 8080
# https : no
#
# ip address : 64.4.94.129
# port : 80
# https : no
#
# ip address : 95.79.36.55
# port : 44861
# https : no
#
# ip address : 107.1.80.135
# port : 80
# https : no
#
# ip address : 103.250.158.23
# port : 61219
# https : no
#
# ip address : 125.141.117.33
# port : 80
# https : no
#
# ip address : 103.107.94.129
# port : 30137
# https : no
#
# ip address : 217.182.168.153
# port : 8080
# https : no
#
# ip address : 1.20.102.228
# port : 58274
# https : yes
#
# ip address : 167.172.109.12
# port : 44465
# https : no
#
# ip address : 118.174.232.148
# port : 55716
# https : no
#
# ip address : 175.100.103.170
# port : 55443
# https : no
#
# ip address : 173.212.202.65
# port : 80
# https : no
#
# ip address : 193.34.55.64
# port : 32767
# https : no
#
# ip address : 122.185.230.189
# port : 80
# https : no
#
# ip address : 5.189.133.231
# port : 80
# https : no
#
# ip address : 185.156.172.122
# port : 3128
# https : yes
#
# ip address : 133.86.253.49
# port : 80
# https : no
#
# ip address : 167.172.191.249
# port : 46377
# https : no
#
# ip address : 180.250.12.10
# port : 80
# https : no
#
# ip address : 212.191.132.210
# port : 8080
# https : yes
#
# ip address : 203.202.245.62
# port : 80
# https : no
#
# ip address : 181.30.60.147
# port : 8080
# https : yes
#
# ip address : 175.103.39.35
# port : 63123
# https : no
#
# ip address : 103.115.14.156
# port : 80
# https : no
#
# ip address : 8.129.217.34
# port : 8888
# https : no
#
# ip address : 119.82.252.76
# port : 51680
# https : no
#
# ip address : 103.115.14.43
# port : 80
# https : no
#
# ip address : 91.211.172.104
# port : 31016
# https : no
#
# ip address : 103.134.254.253
# port : 80
# https : no
#
# ip address : 134.157.93.238
# port : 80
# https : no
#
# ip address : 142.93.223.219
# port : 8080
# https : no
#
# ip address : 38.145.221.44
# port : 808
# https : no
#
# Trying to connect with proxy: 181.30.60.147:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 185.131.60.17:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 1.20.102.228:58274
# Skipping. Connnection error
#
# Trying to connect with proxy: 83.103.193.74:13192
# Skipping. Connnection error
#
# Trying to connect with proxy: 213.105.29.14:3128
# Skipping. Connnection error
#
# Trying to connect with proxy: 185.156.172.122:3128
# Skipping. Connnection error
#
# Trying to connect with proxy: 62.23.15.92:3128
# Skipping. Connnection error
#
# Trying to connect with proxy: 118.27.1.112:3128
# Skipping. Connnection error
#
# Trying to connect with proxy: 179.127.13.148:3128
# Skipping. Connnection error
#
# Trying to connect with proxy: 178.134.155.82:48146
# Skipping. Connnection error
#
# Trying to connect with proxy: 41.65.174.66:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 181.30.60.148:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 208.80.28.208:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 212.191.132.210:8080
# Skipping. Connnection error
#
# Trying to connect with proxy: 193.56.255.133:3128
# Skipping. Connnection error

# %%
# load list of PDFs to scrape
with open('pdf_addresses.data', 'rb') as filehandle:
# read the data as binary data stream
    pdf_addresses = pickle.load(filehandle)

# %% [markdown]
# # The above method uses free proxies, which might cause issues.  Look into using paid proxy servers below, then
# # create function to scrape each opinion from the list (loaded above) into a dataframe
# # create tagging and feature set
# # create models
# # create pipeline
# # create dashboard
#
#
# There are many great paid proxy providers like Smartproxy, Netnut, Highproxies, etc. that can be used when scraping and at least you will know that you will get high-quality services that are safe to use with lots of features and big pools of IPs that you can use.
