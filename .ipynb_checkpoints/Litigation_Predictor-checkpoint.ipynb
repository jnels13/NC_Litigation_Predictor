# %% [markdown]
# # North Carolina Litigation Predictor
# # ADD XGBOOST, INCORPORTE INTO STACKINGCLASSIFIER, FINALIZE
# # Final Preprocessing and Modeling
# ### Contents:
# <ul>
#     <li> Import Libraries
#     <li> Final Preprocessing / One-Hot Encoding
#     <li> Model Creation
#
# </ul>
#
# What's the ultimate outcome?  Just a straight probability of being affirmed is way too high to be indicative of winning a motion.  Perhaps a percentage above or below the dummy classifier, as showing the relative over/under probability as compared to the "average."

# %% [markdown]
# ## Import Libraries & Data

# %%
import io
import pandas as pd
import pickle

import numpy as np
from imblearn.over_sampling import SMOTE, SMOTENC
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.dummy import DummyClassifier
from sklearn import model_selection, naive_bayes, svm
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, RandomizedSearchCV
from collections import defaultdict
from sklearn.metrics import (accuracy_score, classification_report, roc_auc_score,
f1_score, recall_score, precision_score, plot_confusion_matrix, roc_curve, auc)
import xgboost as xgb
import time

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/joenelson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /Users/joenelson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Open the dataframe
infile = open('ProjectData/df_features.data', 'rb')
df = pickle.load(infile)
infile.close()

# %% [markdown]
# ### Review and Clean DataFrame of Unneeded Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 9 columns):
# Opinion                 2665 non-null object
# SCT                     2665 non-null int64
# Year_Filed              2665 non-null int64
# File_Numbers            2665 non-null object
# Result                  2665 non-null int64
# Case_Type               2665 non-null object
# Case_Type_Confidence    2665 non-null object
# Trial_Judge             2665 non-null object
# County                  2665 non-null object
# dtypes: int64(3), object(6)
# memory usage: 187.5+ KB

# %%
df.drop(['Opinion', 'SCT', 'File_Numbers', 'Case_Type_Confidence', 'Year_Filed'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 4 columns):
# Result         2665 non-null int64
# Case_Type      2665 non-null object
# Trial_Judge    2665 non-null object
# County         2665 non-null object
# dtypes: int64(1), object(3)
# memory usage: 83.4+ KB

# %%
df.isna().any()
# Out:
# Result         False
# Case_Type      False
# Trial_Judge    False
# County         False
# dtype: bool

# %%
df.shape
# Out:
# (2665, 4)

# %% [markdown]
# ### One-Hot Encoding and Train/Test Split

# %%
y = df.Result
X = df.drop(columns = ['Result'])

# %%
# Either/Or of the following two:
X_gd = pd.get_dummies(X)
ohe = OneHotEncoder(handle_unknown='ignore')
X_ohe = ohe.fit_transform(X)

# %%
ohe.get_feature_names(X.columns)
# X.columns
# Out:
# array(['Case_Type_car_crash', 'Case_Type_construction',
#        'Case_Type_contract', 'Case_Type_corporate',
#        'Case_Type_defamation', 'Case_Type_employment',
#        'Case_Type_estates', 'Case_Type_family_law',
#        'Case_Type_fraud_udtpa', 'Case_Type_governmental',
#        'Case_Type_insurance', 'Case_Type_landlord_tenant',
#        'Case_Type_med_mal', 'Case_Type_other', 'Case_Type_premises',
#        'Case_Type_products', 'Case_Type_property',
#        'Case_Type_workers_comp', 'Case_Type_wrongful_death',
#        'Trial_Judge_abernathy g.', 'Trial_Judge_abernethy richard',
#        'Trial_Judge_adams gale', 'Trial_Judge_adkins karl',
#        'Trial_Judge_albright', 'Trial_Judge_albright r.',
#        'Trial_Judge_albright robert', 'Trial_Judge_albright stuart',
#        'Trial_Judge_albright w.', 'Trial_Judge_aldridge thomas',
#        'Trial_Judge_alexander karen', 'Trial_Judge_alford benjamin',
#        'Trial_Judge_allen j.', 'Trial_Judge_allen philip',
#        'Trial_Judge_allen stanley', 'Trial_Judge_allen w.',
#        'Trial_Judge_allsbrook richard', 'Trial_Judge_ammons james',
#        'Trial_Judge_anderson charles', 'Trial_Judge_arguments panel',
#        'Trial_Judge_baddour allen', 'Trial_Judge_baddour r.',
#        'Trial_Judge_baddour richard', 'Trial_Judge_baker james',
#        'Trial_Judge_balog steve', 'Trial_Judge_balog steven',
#        'Trial_Judge_banks j.', 'Trial_Judge_barber wade',
#        'Trial_Judge_barefoot napoleon', 'Trial_Judge_barnette henry',
#        'Trial_Judge_barrett sharon', 'Trial_Judge_battle f.',
#        'Trial_Judge_bawtinhimer stacey', 'Trial_Judge_beal',
#        'Trial_Judge_beal beverly', 'Trial_Judge_beale michael',
#        'Trial_Judge_beaman grafton', 'Trial_Judge_bean c.',
#        'Trial_Judge_bedsworth george', 'Trial_Judge_bell j.',
#        'Trial_Judge_bell james', 'Trial_Judge_bell lisa',
#        'Trial_Judge_bell w.', 'Trial_Judge_best kimberly',
#        'Trial_Judge_blackmore rebecca', 'Trial_Judge_blake aretha',
#        'Trial_Judge_bland william', 'Trial_Judge_bledsoe louis',
#        'Trial_Judge_blick joseph', 'Trial_Judge_blount marvin',
#        'Trial_Judge_bogle ronald', 'Trial_Judge_boner richard',
#        'Trial_Judge_bowen wiley', 'Trial_Judge_bowers john',
#        'Trial_Judge_brady robert', 'Trial_Judge_bragg christopher',
#        'Trial_Judge_brannon anthony', 'Trial_Judge_brantley david',
#        'Trial_Judge_braswell b.', 'Trial_Judge_bray susan',
#        'Trial_Judge_brewer coy', 'Trial_Judge_bridges donald',
#        'Trial_Judge_bridges f.', 'Trial_Judge_bridges forrest',
#        'Trial_Judge_bridges kevin', 'Trial_Judge_bridges laura',
#        'Trial_Judge_brooks selina', 'Trial_Judge_brooks william',
#        'Trial_Judge_brown anthony', 'Trial_Judge_brown craig',
#        'Trial_Judge_brown deborah', 'Trial_Judge_brown frank',
#        'Trial_Judge_brown richard', 'Trial_Judge_brown shirley',
#        'Trial_Judge_bryant steven', 'Trial_Judge_bullock stafford',
#        'Trial_Judge_burch susan', 'Trial_Judge_burke l.',
#        'Trial_Judge_burroughs robert', 'Trial_Judge_bushfan elaine',
#        'Trial_Judge_butterfield g.', 'Trial_Judge_caldwell jesse',
#        'Trial_Judge_cameron william', 'Trial_Judge_campbell hugh',
#        'Trial_Judge_carolina the', 'Trial_Judge_carter clarence',
#        'Trial_Judge_cashwell', 'Trial_Judge_cashwell narley',
#        'Trial_Judge_caudill gentry', 'Trial_Judge_caudill j.',
#        'Trial_Judge_caviness', 'Trial_Judge_caviness loto',
#        'Trial_Judge_cayer david', 'Trial_Judge_cella eugene',
#        'Trial_Judge_chapman ronald', 'Trial_Judge_cilley robert',
#        'Trial_Judge_clark giles', 'Trial_Judge_cobb',
#        'Trial_Judge_cobb w.', 'Trial_Judge_cole j.',
#        'Trial_Judge_collier christopher', 'Trial_Judge_collins g.',
#        'Trial_Judge_collins george', 'Trial_Judge_conrad adam',
#        'Trial_Judge_constangy h.', 'Trial_Judge_cooper pell',
#        'Trial_Judge_corbett a.', 'Trial_Judge_corbett albert',
#        'Trial_Judge_cornelius c.', 'Trial_Judge_cornelius preston',
#        'Trial_Judge_corpening j.', 'Trial_Judge_court the',
#        'Trial_Judge_covington mary', 'Trial_Judge_coward william',
#        'Trial_Judge_craig john', 'Trial_Judge_cranford dwight',
#        'Trial_Judge_cromer anderson', 'Trial_Judge_cromer andy',
#        'Trial_Judge_croom craig', 'Trial_Judge_crosswhite joseph',
#        'Trial_Judge_crow kenneth', 'Trial_Judge_daisy william',
#        'Trial_Judge_dameron e.', 'Trial_Judge_davis amber',
#        'Trial_Judge_davis chester', 'Trial_Judge_davis danny',
#        'Trial_Judge_davis j.', 'Trial_Judge_davis james',
#        'Trial_Judge_davis lindsay', 'Trial_Judge_davis richard',
#        'Trial_Judge_davis tommy', 'Trial_Judge_dellinger j.',
#        'Trial_Judge_deramus', 'Trial_Judge_deramus judson',
#        'Trial_Judge_desvousges shelley', 'Trial_Judge_diaz albert',
#        'Trial_Judge_doughton', 'Trial_Judge_doughton richard',
#        'Trial_Judge_downs', 'Trial_Judge_downs james',
#        'Trial_Judge_duke w.', 'Trial_Judge_duncan michael',
#        'Trial_Judge_eagles catherine', 'Trial_Judge_eagles margaret',
#        'Trial_Judge_edwards c.', 'Trial_Judge_ellis b.',
#        'Trial_Judge_ellis craig', 'Trial_Judge_ennis spencer',
#        'Trial_Judge_entzminger daniel', 'Trial_Judge_ervin robert',
#        'Trial_Judge_etheridge scott', 'Trial_Judge_evans pat',
#        'Trial_Judge_evans robert', 'Trial_Judge_evans yvonne',
#        'Trial_Judge_everett clifton', 'Trial_Judge_fairley william',
#        'Trial_Judge_faison james', 'Trial_Judge_farmer robert',
#        'Trial_Judge_ferrell forrest', 'Trial_Judge_finch daniel',
#        'Trial_Judge_fitch milton', 'Trial_Judge_floyd r.',
#        'Trial_Judge_floyd robert', 'Trial_Judge_ford larry',
#        'Trial_Judge_foster anna', 'Trial_Judge_foster jefferey',
#        'Trial_Judge_foster jeffrey', 'Trial_Judge_foster thomas',
#        'Trial_Judge_foust linwood', 'Trial_Judge_fox carl',
#        'Trial_Judge_foy louis', 'Trial_Judge_freeman william',
#        'Trial_Judge_frye henry', 'Trial_Judge_fullwood ernest',
#        'Trial_Judge_fullwood james', 'Trial_Judge_futrell stephan',
#        'Trial_Judge_g howard', 'Trial_Judge_gale james',
#        'Trial_Judge_galloway mark', 'Trial_Judge_gardner john',
#        'Trial_Judge_gavenus gary', 'Trial_Judge_gavin lee',
#        'Trial_Judge_gaylor charles', 'Trial_Judge_gentry mike',
#        'Trial_Judge_gessner paul', 'Trial_Judge_gilchrist c.',
#        'Trial_Judge_ginn c.', 'Trial_Judge_ginn charles',
#        'Trial_Judge_godwin walter', 'Trial_Judge_gordon nancy',
#        'Trial_Judge_gore', 'Trial_Judge_gore william',
#        'Trial_Judge_gorham phyllis', 'Trial_Judge_gottlieb richard',
#        'Trial_Judge_graham', 'Trial_Judge_graham william',
#        'Trial_Judge_grant cy', 'Trial_Judge_gray beecher',
#        'Trial_Judge_gray jane', 'Trial_Judge_gray marvin',
#        'Trial_Judge_greeson howard', 'Trial_Judge_gregory edgar',
#        'Trial_Judge_gregory keith', 'Trial_Judge_griffin william',
#        'Trial_Judge_grimes samuel', 'Trial_Judge_gryder rebecca',
#        'Trial_Judge_guice zoro', 'Trial_Judge_haigwood thomas',
#        'Trial_Judge_hall david', 'Trial_Judge_hamby william',
#        'Trial_Judge_hardin james', 'Trial_Judge_harper jane',
#        'Trial_Judge_harrell r.', 'Trial_Judge_harrison hal',
#        'Trial_Judge_harriss meader', 'Trial_Judge_hartsfield denise',
#        'Trial_Judge_hassell a.', 'Trial_Judge_hassell andrew',
#        'Trial_Judge_heath andrew', 'Trial_Judge_heath elizabeth',
#        'Trial_Judge_hedrick edward', 'Trial_Judge_height henry',
#        'Trial_Judge_helms michael', 'Trial_Judge_helms william',
#        'Trial_Judge_henry charles', 'Trial_Judge_herring d.',
#        'Trial_Judge_hight', 'Trial_Judge_hight henry',
#        'Trial_Judge_hill claire', 'Trial_Judge_hill evelyn',
#        'Trial_Judge_hill james', 'Trial_Judge_hill kendra',
#        'Trial_Judge_hinnant patrice', 'Trial_Judge_hinton alma',
#        'Trial_Judge_hobgood', 'Trial_Judge_hobgood robert',
#        'Trial_Judge_hockenbury jay', 'Trial_Judge_hodges robert',
#        'Trial_Judge_holshouser john', 'Trial_Judge_holt rebecca',
#        'Trial_Judge_holt shelly', 'Trial_Judge_hooks d.',
#        'Trial_Judge_hooks dewey', 'Trial_Judge_hoover donnie',
#        'Trial_Judge_horne gregory', 'Trial_Judge_horne r.',
#        'Trial_Judge_horton clarence', 'Trial_Judge_houston jeanie',
#        'Trial_Judge_hudson orlando', 'Trial_Judge_hughes f.',
#        'Trial_Judge_hunt jeff', 'Trial_Judge_hyatt j.',
#        'Trial_Judge_hyatt marlene', 'Trial_Judge_iii james',
#        'Trial_Judge_inman lucy', 'Trial_Judge_jarrell h.',
#        'Trial_Judge_jenkins jack', 'Trial_Judge_jenkins knox',
#        'Trial_Judge_john joseph', 'Trial_Judge_johnson e.',
#        'Trial_Judge_johnson marcus', 'Trial_Judge_johnson robert',
#        'Trial_Judge_johnston', 'Trial_Judge_johnston robert',
#        'Trial_Judge_jolly jerry', 'Trial_Judge_jolly john',
#        'Trial_Judge_jones abraham', 'Trial_Judge_jones arnold',
#        'Trial_Judge_jones paul', 'Trial_Judge_jones william',
#        'Trial_Judge_jordan lillian', 'Trial_Judge_joseph shannon',
#        'Trial_Judge_keever a.', 'Trial_Judge_key spencer',
#        'Trial_Judge_kincaid timothy', 'Trial_Judge_klass mark',
#        'Trial_Judge_knight peter', 'Trial_Judge_knox michael',
#        'Trial_Judge_kuehnert daniel', 'Trial_Judge_kwasikpui alfred',
#        'Trial_Judge_l lisa', 'Trial_Judge_labarre david',
#        'Trial_Judge_lambeth d.', 'Trial_Judge_lambeth david',
#        'Trial_Judge_lamm charles', 'Trial_Judge_lanier franklin',
#        'Trial_Judge_lanier russell', 'Trial_Judge_lanning james',
#        'Trial_Judge_lassiter melissa', 'Trial_Judge_lawton william',
#        'Trial_Judge_leavell william', 'Trial_Judge_lee jacquelyn',
#        'Trial_Judge_lee w.', 'Trial_Judge_letts bradley',
#        'Trial_Judge_levinson eric', 'Trial_Judge_lewis hugh',
#        'Trial_Judge_lewis john', 'Trial_Judge_lewis ola',
#        'Trial_Judge_lewis robert', 'Trial_Judge_lewis w.',
#        'Trial_Judge_llewellyn james', 'Trial_Judge_lock thomas',
#        'Trial_Judge_locklear gary', 'Trial_Judge_long lunsford',
#        'Trial_Judge_long v.', 'Trial_Judge_long vance',
#        'Trial_Judge_love jimmy', 'Trial_Judge_m craig',
#        'Trial_Judge_maness jayrene', 'Trial_Judge_mangum ned',
#        'Trial_Judge_manning howard', 'Trial_Judge_martin jerry',
#        'Trial_Judge_martin lester', 'Trial_Judge_massey a.',
#        'Trial_Judge_massey moses', 'Trial_Judge_may j.',
#        'Trial_Judge_mccormick edward', 'Trial_Judge_mccoy h.',
#        'Trial_Judge_mcgee martin', 'Trial_Judge_mcguire gregory',
#        'Trial_Judge_mchugh peter', 'Trial_Judge_mckeller c.',
#        'Trial_Judge_mckown ann', 'Trial_Judge_mclean mitchell',
#        'Trial_Judge_mcswain lawrence', 'Trial_Judge_mcthenia paige',
#        'Trial_Judge_miller gordon', 'Trial_Judge_miller regan',
#        'Trial_Judge_mills l.', 'Trial_Judge_morelock fred',
#        'Trial_Judge_morey marcia', 'Trial_Judge_morgan eric',
#        'Trial_Judge_morgan james', 'Trial_Judge_morgan melzer',
#        'Trial_Judge_morgan michael', 'Trial_Judge_morton j.',
#        'Trial_Judge_mullinax robert', 'Trial_Judge_murphy calvin',
#        'Trial_Judge_myers jimmy', 'Trial_Judge_n cressie',
#        'Trial_Judge_n nancy', 'Trial_Judge_nan',
#        'Trial_Judge_nance commissioner', 'Trial_Judge_noble l.',
#        'Trial_Judge_noble lucy', 'Trial_Judge_noble oliver',
#        'Trial_Judge_nobles john', 'Trial_Judge_norelli nancy',
#        'Trial_Judge_ofoghludha michael', 'Trial_Judge_oneal elaine',
#        'Trial_Judge_orders walter', 'Trial_Judge_osman matthew',
#        'Trial_Judge_overby donald', 'Trial_Judge_parker j.',
#        'Trial_Judge_parker regina', 'Trial_Judge_parker richard',
#        'Trial_Judge_parsons w.', 'Trial_Judge_patti',
#        'Trial_Judge_patti timothy', 'Trial_Judge_payne ronald',
#        'Trial_Judge_penry j.', 'Trial_Judge_phillips herbert',
#        'Trial_Judge_pittman william', 'Trial_Judge_pomeroy w.',
#        'Trial_Judge_pool c.', 'Trial_Judge_poovey nathaniel',
#        'Trial_Judge_pope marvin', 'Trial_Judge_powell mark',
#        'Trial_Judge_quinn paul', 'Trial_Judge_r allen',
#        'Trial_Judge_r wade', 'Trial_Judge_rader robert',
#        'Trial_Judge_ragan james', 'Trial_Judge_rand ripley',
#        'Trial_Judge_reviewable and', 'Trial_Judge_ridgeway paul',
#        'Trial_Judge_roberson james', 'Trial_Judge_robinson michael',
#        'Trial_Judge_roda peter', 'Trial_Judge_roemer victoria',
#        'Trial_Judge_ross thomas', 'Trial_Judge_rousseau julius',
#        'Trial_Judge_royster ted', 'Trial_Judge_royster theodore',
#        'Trial_Judge_ruled ronald', 'Trial_Judge_s james',
#        'Trial_Judge_salisbury anne', 'Trial_Judge_sasser debra',
#        'Trial_Judge_sasser douglas', 'Trial_Judge_saunders chase',
#        'Trial_Judge_scarlett beverly', 'Trial_Judge_scott ward',
#        'Trial_Judge_seaton sarah', 'Trial_Judge_seay thomas',
#        'Trial_Judge_sermons wayland', 'Trial_Judge_sharpe margaret',
#        'Trial_Judge_shirley a.', 'Trial_Judge_sitton claude',
#        'Trial_Judge_smith donald', 'Trial_Judge_smith john',
#        'Trial_Judge_smith osmond', 'Trial_Judge_smith sean',
#        'Trial_Judge_smith timothy', 'Trial_Judge_smith w.',
#        'Trial_Judge_southern william', 'Trial_Judge_spainhour w.',
#        'Trial_Judge_spencer', 'Trial_Judge_spencer cheryl',
#        'Trial_Judge_spencer james', 'Trial_Judge_spivey ronald',
#        'Trial_Judge_stanback a.', 'Trial_Judge_stanback leon',
#        'Trial_Judge_staton kimberly', 'Trial_Judge_steelman sanford',
#        'Trial_Judge_stephens donald', 'Trial_Judge_stephens ronald',
#        'Trial_Judge_stewart caron', 'Trial_Judge_stiehl robert',
#        'Trial_Judge_stone richard', 'Trial_Judge_strickland david',
#        'Trial_Judge_strickland james', 'Trial_Judge_stubbs alice',
#        'Trial_Judge_sturges cindy', 'Trial_Judge_sumner quentin',
#        'Trial_Judge_sumner robert', 'Trial_Judge_sutton david',
#        'Trial_Judge_t entering', 'Trial_Judge_tally mary',
#        'Trial_Judge_taylor kim', 'Trial_Judge_taylor kimberly',
#        'Trial_Judge_taylor susan', 'Trial_Judge_tennille ben',
#        'Trial_Judge_thalheimer ben', 'Trial_Judge_that to',
#        'Trial_Judge_thigpen cressie', 'Trial_Judge_thompson carolyn',
#        'Trial_Judge_thompson jack', 'Trial_Judge_thornburg alan',
#        'Trial_Judge_tilghman carl', 'Trial_Judge_tillery bradford',
#        'Trial_Judge_tillet jerry', 'Trial_Judge_tillett jerry',
#        'Trial_Judge_titus kenneth', 'Trial_Judge_trawick gary',
#        'Trial_Judge_trivette robert', 'Trial_Judge_trosch elizabeth',
#        'Trial_Judge_trosch louis', 'Trial_Judge_tucker kimbrell',
#        'Trial_Judge_turner joseph', 'Trial_Judge_turner r.',
#        'Trial_Judge_vosburg james', 'Trial_Judge_vosburgh james',
#        'Trial_Judge_waddell jerry', 'Trial_Judge_wagoner anna',
#        'Trial_Judge_wainwright george', 'Trial_Judge_walczyk christine',
#        'Trial_Judge_walker richard', 'Trial_Judge_walker russell',
#        'Trial_Judge_wallace tanya', 'Trial_Judge_ward j.',
#        'Trial_Judge_warren raymond', 'Trial_Judge_warren steve',
#        'Trial_Judge_watson ebern', 'Trial_Judge_webb james',
#        'Trial_Judge_weeks gregory', 'Trial_Judge_wiggins lamont',
#        'Trial_Judge_wijewickrama roy', 'Trial_Judge_wilhelm christy',
#        'Trial_Judge_willey joshua', 'Trial_Judge_williams joseph',
#        'Trial_Judge_williams karen', 'Trial_Judge_williamson f.',
#        'Trial_Judge_wilson edwin', 'Trial_Judge_winner dennis',
#        'Trial_Judge_wood william', 'Trial_Judge_you will',
#        'Trial_Judge_z albert', 'Trial_Judge_zimmerman h.', 'County_a',
#        'County_alamance', 'County_alexander', 'County_alleghany',
#        'County_and', 'County_another', 'County_anson', 'County_ashe',
#        'County_avery', 'County_beaufort', 'County_bertie',
#        'County_bladen', 'County_brunswick', 'County_buncombe',
#        'County_burke', 'County_cabarrus', 'County_caldwell',
#        'County_camden', 'County_carteret', 'County_caswell',
#        'County_catawba', 'County_chatham', 'County_cherokee',
#        'County_chowan', 'County_claiborne', 'County_cleveland',
#        'County_columbus', 'County_consolidated', 'County_craven',
#        'County_cumberland', 'County_currituck', 'County_dare',
#        'County_davidson', 'County_davie', 'County_duplin',
#        'County_durham', 'County_edgecombe', 'County_forsyth',
#        'County_four', 'County_franklin', 'County_gaston', 'County_gates',
#        'County_graham', 'County_granville', 'County_greene',
#        'County_guilford', 'County_halifax', 'County_hanover',
#        'County_harnett', 'County_haywood', 'County_henderson',
#        'County_hertford', 'County_hoke', 'County_hyde', 'County_iredell',
#        'County_jackson', 'County_johnston', 'County_jones', 'County_lee',
#        'County_lenoir', 'County_lincoln', 'County_macon',
#        'County_madison', 'County_martin', 'County_mcdowell',
#        'County_mecklenberg', 'County_mecklenburg', 'County_mitchell',
#        'County_montgomery', 'County_moore', 'County_nash',
#        'County_northampton', 'County_northhampton', 'County_onslow',
#        'County_orange', 'County_pamlico', 'County_pasquotank',
#        'County_pender', 'County_perquimans', 'County_person',
#        'County_pitt', 'County_polk', 'County_proper', 'County_randolph',
#        'County_richmond', 'County_robeson', 'County_rockingham',
#        'County_rowan', 'County_rutherford', 'County_sampson',
#        'County_scotland', 'County_stanly', 'County_stokes',
#        'County_surry', 'County_swain', 'County_the',
#        'County_transylvania', 'County_union', 'County_vance',
#        'County_wake', 'County_warren', 'County_washington',
#        'County_watauga', 'County_wayne', 'County_wilkes', 'County_wilson',
#        'County_yadkin', 'County_yancey'], dtype=object)

# %%
X_gd.shape, X_ohe.shape
# Out:
# ((2665, 605), (2665, 605))

# %%
# View class imbalance
y.value_counts()
# Out:
# 1    1984
# 0     681
# Name: Result, dtype: int64

# %%
#Visualize class imbalance
y.value_counts().plot.pie(autopct="%.1f%%")

# %%
# USING X_ohe - SWITCH OUT IF DESIRED
X_train_unbalanced, X_test, y_train_unbalanced, y_test = train_test_split(X_ohe,y,random_state = 42, test_size = 0.3)

# %%
# sm = SMOTE(sampling_strategy='auto', k_neighbors=2, random_state=42)
# X_train ,y_train = sm.fit_resample(X_train, y_train) 

indices = [i for i in range(len(X.columns))]
smnc = SMOTENC(categorical_features=indices, random_state=42, sampling_strategy='not majority')
X_train, y_train = smnc.fit_resample(X_train_unbalanced, y_train_unbalanced)

# %%
pd.Series(y_train).value_counts().plot.pie(autopct="%.1f%%");

# %%
X_train.shape, y_train.shape
# Out:
# ((2760, 605), (2760,))

# %% [markdown]
# # Modeling
#
# Some research into the best probabilistic classification models suggests that logistic regression, SVMs, and neural networks would be the best fit for the intended goal.  I will run each on the data and see which performs best.

# %% [markdown]
# ## Set Baseline with Dummy Classifier

# %%
def dummy_classifier(X_train_unbalanced, X_test, y_train_unbalanced, y_test):
    dummy_clf = DummyClassifier(strategy="stratified", random_state=42)
    dummy_clf.fit(X_train, y_train)
    y_hat = dummy_clf.predict(X_test)
    print('Classification Report:\n', classification_report(y_test, y_hat), '\n',
          plot_confusion_matrix(dummy_clf, X_test, y_test, cmap='GnBu', values_format = '.5g'), 
          plt.show())
    return()

# %%
dummy_classifier(X_train, X_test, y_train, y_test)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.24      0.50      0.32       196
#            1       0.75      0.49      0.59       604
#
#     accuracy                           0.49       800
#    macro avg       0.50      0.49      0.46       800
# weighted avg       0.63      0.49      0.53       800
#
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f82c1d3df60> None
# ()

# %% [markdown]
# DUMMY CLASSIFIER sets a baseline for the next few models with a baseline accuracy of .49 and precision of 0.24/0.75 for classes 0/1 respectively.

# %% [markdown]
# ## Logistic Regression Model

# %%
def logreg_fn(X_train, X_test, y_train, y_test, params):
    logreg_clf = LogisticRegression(random_state=12)
    logreg_gs = GridSearchCV(logreg_clf, params, cv=5)
    logreg_gs.fit(X_train, y_train)
    best = logreg_gs.best_params_
    logreg_final = LogisticRegression(solver=best['solver'],
                                      penalty=best['penalty'],
                                      C=best['C'], 
                                      random_state=12)
    logreg_final.fit(X_train, y_train)
    y_hat = logreg_final.predict(X_test)
    print('Best params:',best,
          '\n\nClassification Report:\n', classification_report(y_test, y_hat), '\n',
          plot_confusion_matrix(logreg_final, X_test, y_test, cmap='GnBu', values_format = '.5g'), 
          plt.show())
    return(best)

# %%
parameters = {'C':[750,500,100], 
              'penalty':['l1', 'l2', 'elasticnet', 'none'],
              'solver':['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']}

best_lr=logreg_fn(X_train_unbalanced, X_test, y_train_unbalanced, y_test, parameters)
# Out:
# Best params: {'C': 750, 'penalty': 'none', 'solver': 'lbfgs'}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.28      0.35      0.31       196
#            1       0.77      0.71      0.74       604
#
#     accuracy                           0.62       800
#    macro avg       0.53      0.53      0.53       800
# weighted avg       0.65      0.62      0.64       800
#
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f82ae7d9e80> None

# %% [markdown]
# This model certainly improved over baseline, with accuracy increasing to .62 (a 27% increase over baseline).  However, this is still far from an ideal number. <br>
# Same accuracy for unbalanced data (0.62, f1 of .74)

# %% [markdown]
# **Dropped Year_Filed: there's no reason this should be an input, resulted in better performance time-wise, but AUC still is dismal:**<br>
# Best params: {'C': 100, 'penalty': 'none', 'solver': 'lbfgs'} <br>
#  Accuracy Score - Test:  0.6225 <br>
#  Confusion Matrix: <br>
#  [[ 59 134]<br>
#  [168 439]] <br>
#  <br>**Predicted on Trial_Judge and Case_Type:**<br>
#  Best params: {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'} <br>
#  Accuracy Score - Test:  0.62375 <br>
#  Confusion Matrix:<br>
#  [[ 54 139]<br>
#  [162 445]] <br>
#  **Predicting on Case_Type Only:**<br>
#  Best params: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'} <br>
#  Accuracy Score - Test:  0.57375 <br>
#  Confusion Matrix:<br>
#  [[ 74 119]<br>
#  [222 385]] <br>
#  **Predicting on Trial_Judge Only:**<br>
#  Best params: {'C': 10, 'penalty': 'l2', 'solver': 'saga'}  <br>
#  Accuracy Score - Test:  0.56375  <br>
#  Confusion Matrix: <br>
#  [[ 65 128] <br>
#  [221 386]]  <br>

# %% [markdown]
# ## Neural Network

# %%
from numpy import loadtxt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import keras_metrics as km

# %%
tf.random.set_random_seed(7)
model = Sequential()
model.add(Dense(16, input_dim=605, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
recall = km.binary_recall(label=0)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', recall])

# %%
history = model.fit(X_train_unbalanced, y_train_unbalanced, epochs=100, validation_split=0.2, batch_size=32)
# Out:
# Train on 1492 samples, validate on 373 samples
# Epoch 1/100
# 1492/1492 [==============================] - 1s 665us/step - loss: 0.6735 - acc: 0.7165 - recall: 0.9512 - val_loss: 0.6572 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 2/100
# 1492/1492 [==============================] - 0s 80us/step - loss: 0.6385 - acc: 0.7393 - recall: 0.9964 - val_loss: 0.6170 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 3/100
# 1492/1492 [==============================] - 0s 73us/step - loss: 0.6068 - acc: 0.7420 - recall: 1.0000 - val_loss: 0.5975 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 4/100
# 1492/1492 [==============================] - 0s 70us/step - loss: 0.5904 - acc: 0.7406 - recall: 0.9991 - val_loss: 0.5869 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 5/100
# 1492/1492 [==============================] - 0s 70us/step - loss: 0.5934 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5852 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 6/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.5883 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5835 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 7/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5781 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5822 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 8/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5822 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5821 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 9/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5871 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5820 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 10/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5754 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5816 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 11/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5765 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5813 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 12/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5759 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5816 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 13/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5781 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5820 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 14/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5773 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5825 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 15/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5609 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5830 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 16/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5575 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5849 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 17/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5553 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5849 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 18/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.5570 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5854 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 19/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5534 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5862 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 20/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5469 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5883 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 21/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.5434 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5907 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 22/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.5289 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5973 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 23/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5325 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.5975 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 24/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5323 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6022 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 25/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.5145 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6184 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 26/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.5197 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6215 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 27/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5059 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6270 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 28/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5008 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6392 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 29/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.4854 - acc: 0.7413 - recall: 1.0000 - val_loss: 0.6619 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 30/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5066 - acc: 0.7420 - recall: 1.0000 - val_loss: 0.6539 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 31/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.5034 - acc: 0.7420 - recall: 1.0000 - val_loss: 0.6625 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 32/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4841 - acc: 0.7406 - recall: 0.9964 - val_loss: 0.6812 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 33/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.4720 - acc: 0.7420 - recall: 0.9910 - val_loss: 0.7025 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 34/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4732 - acc: 0.7500 - recall: 0.9892 - val_loss: 0.7173 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 35/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.4509 - acc: 0.7446 - recall: 0.9638 - val_loss: 0.7489 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 36/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4455 - acc: 0.7547 - recall: 0.9494 - val_loss: 0.7699 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 37/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4466 - acc: 0.7661 - recall: 0.9575 - val_loss: 0.7998 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 38/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4280 - acc: 0.7647 - recall: 0.9503 - val_loss: 0.8592 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 39/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.4413 - acc: 0.7601 - recall: 0.9385 - val_loss: 0.8271 - val_acc: 0.7346 - val_recall: 1.0000
# Epoch 40/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.4051 - acc: 0.7902 - recall: 0.9548 - val_loss: 0.9336 - val_acc: 0.7239 - val_recall: 0.9818
# Epoch 41/100
# 1492/1492 [==============================] - 0s 68us/step - loss: 0.4393 - acc: 0.7674 - recall: 0.9322 - val_loss: 0.8788 - val_acc: 0.6944 - val_recall: 0.9343
# Epoch 42/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.4304 - acc: 0.7594 - recall: 0.9195 - val_loss: 0.9613 - val_acc: 0.7239 - val_recall: 0.9818
# Epoch 43/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.4149 - acc: 0.7721 - recall: 0.9421 - val_loss: 0.9323 - val_acc: 0.6810 - val_recall: 0.9124
# Epoch 44/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3942 - acc: 0.7768 - recall: 0.9385 - val_loss: 1.0329 - val_acc: 0.6461 - val_recall: 0.8467
# Epoch 45/100
# 1492/1492 [==============================] - 0s 67us/step - loss: 0.3964 - acc: 0.7815 - recall: 0.9349 - val_loss: 1.0418 - val_acc: 0.6515 - val_recall: 0.8321
# Epoch 46/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.3776 - acc: 0.7849 - recall: 0.9403 - val_loss: 1.1364 - val_acc: 0.6488 - val_recall: 0.8285
# Epoch 47/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3710 - acc: 0.7882 - recall: 0.9277 - val_loss: 1.1658 - val_acc: 0.6542 - val_recall: 0.8285
# Epoch 48/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.3875 - acc: 0.7862 - recall: 0.9204 - val_loss: 1.2471 - val_acc: 0.6488 - val_recall: 0.8248
# Epoch 49/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.3667 - acc: 0.8023 - recall: 0.9304 - val_loss: 1.2920 - val_acc: 0.6702 - val_recall: 0.8540
# Epoch 50/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.3460 - acc: 0.8050 - recall: 0.9286 - val_loss: 1.3899 - val_acc: 0.6595 - val_recall: 0.8431
# Epoch 51/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3528 - acc: 0.7842 - recall: 0.9132 - val_loss: 1.3920 - val_acc: 0.6542 - val_recall: 0.8358
# Epoch 52/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3454 - acc: 0.8076 - recall: 0.9259 - val_loss: 1.4344 - val_acc: 0.6622 - val_recall: 0.8467
# Epoch 53/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3408 - acc: 0.8097 - recall: 0.9213 - val_loss: 1.5341 - val_acc: 0.6702 - val_recall: 0.8650
# Epoch 54/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3273 - acc: 0.8070 - recall: 0.9231 - val_loss: 1.5756 - val_acc: 0.6676 - val_recall: 0.8650
# Epoch 55/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.3357 - acc: 0.7936 - recall: 0.9231 - val_loss: 1.6201 - val_acc: 0.6568 - val_recall: 0.8467
# Epoch 56/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3312 - acc: 0.7996 - recall: 0.9195 - val_loss: 1.5960 - val_acc: 0.6568 - val_recall: 0.8248
# Epoch 57/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3371 - acc: 0.8070 - recall: 0.9313 - val_loss: 1.6868 - val_acc: 0.6461 - val_recall: 0.8248
# Epoch 58/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3216 - acc: 0.8103 - recall: 0.9259 - val_loss: 1.6981 - val_acc: 0.6542 - val_recall: 0.8248
# Epoch 59/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.3288 - acc: 0.7895 - recall: 0.9060 - val_loss: 1.7045 - val_acc: 0.6515 - val_recall: 0.8212
# Epoch 60/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3041 - acc: 0.8157 - recall: 0.9313 - val_loss: 1.7689 - val_acc: 0.6488 - val_recall: 0.8212
# Epoch 61/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.3109 - acc: 0.8063 - recall: 0.9241 - val_loss: 1.7962 - val_acc: 0.6515 - val_recall: 0.8212
# Epoch 62/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.3042 - acc: 0.8023 - recall: 0.9195 - val_loss: 1.8404 - val_acc: 0.6488 - val_recall: 0.8139
# Epoch 63/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2896 - acc: 0.8043 - recall: 0.9241 - val_loss: 1.9587 - val_acc: 0.6542 - val_recall: 0.8431
# Epoch 64/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2876 - acc: 0.8170 - recall: 0.9358 - val_loss: 2.0023 - val_acc: 0.6622 - val_recall: 0.8467
# Epoch 65/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2947 - acc: 0.8117 - recall: 0.9340 - val_loss: 2.0115 - val_acc: 0.6568 - val_recall: 0.8431
# Epoch 66/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2888 - acc: 0.8164 - recall: 0.9322 - val_loss: 2.0553 - val_acc: 0.6542 - val_recall: 0.8431
# Epoch 67/100
# 1492/1492 [==============================] - 0s 69us/step - loss: 0.2913 - acc: 0.8271 - recall: 0.9277 - val_loss: 2.0485 - val_acc: 0.6568 - val_recall: 0.8321
# Epoch 68/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.2892 - acc: 0.8613 - recall: 0.8861 - val_loss: 2.0199 - val_acc: 0.6542 - val_recall: 0.8248
# Epoch 69/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2724 - acc: 0.8639 - recall: 0.8861 - val_loss: 2.1277 - val_acc: 0.6568 - val_recall: 0.8321
# Epoch 70/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2720 - acc: 0.8666 - recall: 0.8770 - val_loss: 2.1935 - val_acc: 0.6542 - val_recall: 0.8358
# Epoch 71/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2752 - acc: 0.8653 - recall: 0.8671 - val_loss: 2.2172 - val_acc: 0.6649 - val_recall: 0.8431
# Epoch 72/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2758 - acc: 0.8773 - recall: 0.8716 - val_loss: 2.2843 - val_acc: 0.6568 - val_recall: 0.8431
# Epoch 73/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2706 - acc: 0.8820 - recall: 0.8788 - val_loss: 2.3340 - val_acc: 0.6622 - val_recall: 0.8467
# Epoch 74/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2649 - acc: 0.8807 - recall: 0.8725 - val_loss: 2.2984 - val_acc: 0.6649 - val_recall: 0.8467
# Epoch 75/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2558 - acc: 0.8981 - recall: 0.8797 - val_loss: 2.3495 - val_acc: 0.6595 - val_recall: 0.8394
# Epoch 76/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2770 - acc: 0.8834 - recall: 0.8599 - val_loss: 2.4137 - val_acc: 0.6488 - val_recall: 0.8394
# Epoch 77/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2664 - acc: 0.8834 - recall: 0.8608 - val_loss: 2.3975 - val_acc: 0.6515 - val_recall: 0.8358
# Epoch 78/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2548 - acc: 0.8981 - recall: 0.8788 - val_loss: 2.4821 - val_acc: 0.6515 - val_recall: 0.8504
# Epoch 79/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2585 - acc: 0.8995 - recall: 0.8834 - val_loss: 2.4516 - val_acc: 0.6515 - val_recall: 0.8212
# Epoch 80/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2531 - acc: 0.8934 - recall: 0.8707 - val_loss: 2.4129 - val_acc: 0.6461 - val_recall: 0.8212
# Epoch 81/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2462 - acc: 0.9021 - recall: 0.8825 - val_loss: 2.4659 - val_acc: 0.6542 - val_recall: 0.8358
# Epoch 82/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2640 - acc: 0.8834 - recall: 0.8571 - val_loss: 2.5367 - val_acc: 0.6542 - val_recall: 0.8394
# Epoch 83/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2350 - acc: 0.8968 - recall: 0.8734 - val_loss: 2.6081 - val_acc: 0.6542 - val_recall: 0.8467
# Epoch 84/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2538 - acc: 0.8881 - recall: 0.8580 - val_loss: 2.6691 - val_acc: 0.6515 - val_recall: 0.8431
# Epoch 85/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2484 - acc: 0.8941 - recall: 0.8671 - val_loss: 2.6765 - val_acc: 0.6515 - val_recall: 0.8431
# Epoch 86/100
# 1492/1492 [==============================] - 0s 79us/step - loss: 0.2572 - acc: 0.8874 - recall: 0.8617 - val_loss: 2.6625 - val_acc: 0.6568 - val_recall: 0.8394
# Epoch 87/100
# 1492/1492 [==============================] - 0s 68us/step - loss: 0.2419 - acc: 0.8934 - recall: 0.8635 - val_loss: 2.6745 - val_acc: 0.6568 - val_recall: 0.8431
# Epoch 88/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2564 - acc: 0.8881 - recall: 0.8635 - val_loss: 2.7303 - val_acc: 0.6542 - val_recall: 0.8431
# Epoch 89/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2486 - acc: 0.8881 - recall: 0.8580 - val_loss: 2.7283 - val_acc: 0.6461 - val_recall: 0.8321
# Epoch 90/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2476 - acc: 0.8988 - recall: 0.8734 - val_loss: 2.6849 - val_acc: 0.6461 - val_recall: 0.8248
# Epoch 91/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2367 - acc: 0.9048 - recall: 0.8834 - val_loss: 2.8270 - val_acc: 0.6595 - val_recall: 0.8650
# Epoch 92/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.2354 - acc: 0.8961 - recall: 0.8725 - val_loss: 2.7111 - val_acc: 0.6542 - val_recall: 0.8394
# Epoch 93/100
# 1492/1492 [==============================] - 0s 65us/step - loss: 0.2415 - acc: 0.8941 - recall: 0.8653 - val_loss: 2.7291 - val_acc: 0.6595 - val_recall: 0.8394
# Epoch 94/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2294 - acc: 0.8995 - recall: 0.8734 - val_loss: 2.7735 - val_acc: 0.6649 - val_recall: 0.8613
# Epoch 95/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2246 - acc: 0.9021 - recall: 0.8779 - val_loss: 2.7884 - val_acc: 0.6676 - val_recall: 0.8650
# Epoch 96/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2326 - acc: 0.8968 - recall: 0.8689 - val_loss: 2.7523 - val_acc: 0.6515 - val_recall: 0.8358
# Epoch 97/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2242 - acc: 0.9008 - recall: 0.8743 - val_loss: 2.8385 - val_acc: 0.6676 - val_recall: 0.8540
# Epoch 98/100
# 1492/1492 [==============================] - 0s 64us/step - loss: 0.2385 - acc: 0.8995 - recall: 0.8734 - val_loss: 2.8053 - val_acc: 0.6568 - val_recall: 0.8431
# Epoch 99/100
# 1492/1492 [==============================] - 0s 66us/step - loss: 0.2206 - acc: 0.9055 - recall: 0.8834 - val_loss: 2.8957 - val_acc: 0.6729 - val_recall: 0.8650
# Epoch 100/100
# 1492/1492 [==============================] - 0s 63us/step - loss: 0.2233 - acc: 0.9015 - recall: 0.8734 - val_loss: 2.9112 - val_acc: 0.6568 - val_recall: 0.8504

# %%
results = model.evaluate(X_test, y_test, batch_size=10)
print('Loss: ', (results[0]),
      '\nAccuracy: ',(results[1]),
      '\nRecall: ',(results[2]))
# Out:
# 800/800 [==============================] - 0s 144us/step
# Loss:  2.557055826066062
# Accuracy:  0.6875000014901161
# Recall:  0.8410596025097584

# %%
print(history.history.keys())
#  "Accuracy"
plt.figure(figsize=(10,5))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
# "Loss"
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_recall', 'loss', 'acc', 'recall'])

# %% [markdown]
# **Results on Test Set -- last at the bottom **
#
# 3 Dense Layers (16/8/1), 100 epochs, 0.2 validation split, batch size 10<br>
# Loss:  2.7501846364699305 <br>
# Accuracy:  0.6687500029802322 <br>
# Recall:  0.8162251654277773<br>
# On the loss plot, the loss on the training data remains fairly constant, while the validation loss increases,
#
#
# 3 Dense Layers (16/8/1) with dropout(0.5) after 2nd Dense, 100 epochs, 0.2 validation split, batch size 20, Changed to unbalanced data: <br>
# Loss:  3.7459801264107226 <br>
# Accuracy:  0.6387500042095781 <br>
# Recall:  0.761589403847419<br>
# On the loss plot, both training and validation dropped, but validation climbed thereafter, train continued to decline.
#
# Above, but add second Dropout after activation layer, change both Dropouts to 0.2:<br>
# Loss:  2.2827060595154762 <br>
# Accuracy:  0.6775000037625432 <br>
# Recall:  0.824503311121771<br>
# Loss plot shows initial cross (1st or 2nd epoch) but then smoothly divergent curves. <br><br>
# Above, but change batch size to 50:
# Loss:  2.543306863121688 <br>
# Accuracy:  0.6875000027939677<br>
# Recall:  0.8427152316485571<br>
# Loss plot shows to distinct straight-ish lines, with validation slowly increasing but train staying constant. <br>
# <br>
# Above, but change batch size to 32:<br>
# Loss:  3.0654561286384707 <br>
# Accuracy:  0.6887500001117587 <br>
# Recall:  0.8493377482037521<br>
# Loss plot still very disparate.<br>
# <br>
# RETURN to balanced data since both classes matter, increase both dropouts to 0.3, 16/8/1, batch size 32, 100 epochs:<br>**
# Loss:  1.8901734507875516 <br>
# Accuracy:  0.6712500041350722 <br>
# Recall:  0.8261589402605698<br>
# Loss plot conjoins! Training/validation accuracy maxes out around 0.9, though test accuracy hasn't really changed.  RE-RAN with 200 epochs, loss begins to diverge at 120; trimmed a little to the final neural net model:
# <br><br>
# **--------------------------------------------------------------------------------<br>
# RETURN to balanced data since both classes matter, added another hidden layer with a dropout layer, increase all dropouts to 0.3, 16/8/8/1, batch size 32, 100 epochs:<br>**
# Loss:  2.6436448619075237 <br>
# Accuracy:  0.6862500000745058 <br>
# Recall:  0.8476821190649534<br>
# <br><br>
# Balanced data, loss still diverges: added layers, changed dropouts ... will try to run unbalanced data stacking classifier without nn.

# %%
j=model.predict_proba(X_test).round(3)

# %%
j
# Out:
# array([[0.992],
#        [0.013],
#        [0.998],
#        [0.981],
#        [0.   ],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [0.959],
#        [0.995],
#        [0.   ],
#        [0.995],
#        [0.994],
#        [0.032],
#        [0.999],
#        [0.954],
#        [0.991],
#        [0.89 ],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [0.99 ],
#        [0.997],
#        [0.908],
#        [0.998],
#        [1.   ],
#        [0.994],
#        [1.   ],
#        [0.   ],
#        [0.999],
#        [1.   ],
#        [0.997],
#        [1.   ],
#        [0.994],
#        [1.   ],
#        [0.423],
#        [1.   ],
#        [0.998],
#        [0.987],
#        [1.   ],
#        [0.002],
#        [0.993],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [0.979],
#        [1.   ],
#        [1.   ],
#        [0.989],
#        [0.341],
#        [1.   ],
#        [0.24 ],
#        [1.   ],
#        [1.   ],
#        [0.981],
#        [0.983],
#        [0.964],
#        [0.952],
#        [0.974],
#        [0.991],
#        [0.247],
#        [0.999],
#        [0.068],
#        [0.993],
#        [0.88 ],
#        [0.401],
#        [1.   ],
#        [0.945],
#        [0.991],
#        [0.112],
#        [0.   ],
#        [1.   ],
#        [0.997],
#        [0.968],
#        [1.   ],
#        [0.281],
#        [0.868],
#        [0.991],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.962],
#        [0.964],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.995],
#        [0.071],
#        [0.003],
#        [1.   ],
#        [1.   ],
#        [0.996],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.931],
#        [0.982],
#        [0.996],
#        [0.997],
#        [1.   ],
#        [1.   ],
#        [0.815],
#        [0.998],
#        [1.   ],
#        [1.   ],
#        [0.967],
#        [0.987],
#        [1.   ],
#        [0.999],
#        [0.413],
#        [1.   ],
#        [0.   ],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [1.   ],
#        [0.788],
#        [1.   ],
#        [1.   ],
#        [0.98 ],
#        [0.483],
#        [1.   ],
#        [1.   ],
#        [0.982],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.993],
#        [0.004],
#        [0.13 ],
#        [0.991],
#        [1.   ],
#        [0.   ],
#        [0.949],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.992],
#        [0.35 ],
#        [0.795],
#        [1.   ],
#        [0.972],
#        [0.293],
#        [0.997],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.547],
#        [0.991],
#        [0.999],
#        [0.898],
#        [0.993],
#        [0.998],
#        [0.033],
#        [0.911],
#        [0.966],
#        [0.999],
#        [1.   ],
#        [0.935],
#        [0.057],
#        [0.999],
#        [0.994],
#        [0.995],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [0.999],
#        [1.   ],
#        [0.404],
#        [1.   ],
#        [0.   ],
#        [0.999],
#        [0.999],
#        [0.985],
#        [0.865],
#        [0.994],
#        [1.   ],
#        [1.   ],
#        [0.99 ],
#        [1.   ],
#        [0.895],
#        [0.094],
#        [0.007],
#        [0.977],
#        [1.   ],
#        [1.   ],
#        [0.957],
#        [0.106],
#        [0.999],
#        [0.008],
#        [0.99 ],
#        [1.   ],
#        [0.16 ],
#        [0.973],
#        [0.966],
#        [0.983],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [1.   ],
#        [0.974],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.093],
#        [1.   ],
#        [0.997],
#        [1.   ],
#        [0.999],
#        [0.771],
#        [0.999],
#        [0.974],
#        [0.998],
#        [0.975],
#        [0.937],
#        [0.989],
#        [1.   ],
#        [0.957],
#        [0.998],
#        [1.   ],
#        [0.999],
#        [1.   ],
#        [0.994],
#        [0.04 ],
#        [1.   ],
#        [0.9  ],
#        [0.993],
#        [0.994],
#        [0.999],
#        [1.   ],
#        [0.999],
#        [0.002],
#        [0.99 ],
#        [0.036],
#        [0.95 ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.983],
#        [0.002],
#        [0.902],
#        [0.629],
#        [1.   ],
#        [0.977],
#        [1.   ],
#        [0.   ],
#        [0.908],
#        [0.957],
#        [0.982],
#        [0.002],
#        [1.   ],
#        [0.999],
#        [0.   ],
#        [0.999],
#        [0.925],
#        [0.533],
#        [1.   ],
#        [0.037],
#        [1.   ],
#        [1.   ],
#        [0.996],
#        [0.999],
#        [0.994],
#        [0.978],
#        [1.   ],
#        [1.   ],
#        [0.965],
#        [0.87 ],
#        [0.736],
#        [0.988],
#        [0.999],
#        [1.   ],
#        [0.872],
#        [0.972],
#        [0.147],
#        [1.   ],
#        [0.   ],
#        [0.997],
#        [1.   ],
#        [1.   ],
#        [0.983],
#        [0.   ],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.995],
#        [0.909],
#        [0.968],
#        [1.   ],
#        [0.996],
#        [0.988],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.011],
#        [0.995],
#        [1.   ],
#        [1.   ],
#        [0.909],
#        [0.937],
#        [0.83 ],
#        [1.   ],
#        [0.984],
#        [1.   ],
#        [0.048],
#        [0.996],
#        [1.   ],
#        [1.   ],
#        [0.978],
#        [1.   ],
#        [0.999],
#        [0.998],
#        [0.   ],
#        [0.996],
#        [0.105],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [0.996],
#        [0.   ],
#        [1.   ],
#        [0.999],
#        [1.   ],
#        [0.96 ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [0.043],
#        [1.   ],
#        [0.991],
#        [0.766],
#        [1.   ],
#        [0.997],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.998],
#        [0.999],
#        [0.678],
#        [0.875],
#        [0.959],
#        [0.934],
#        [0.948],
#        [0.   ],
#        [0.   ],
#        [1.   ],
#        [1.   ],
#        [0.164],
#        [0.999],
#        [0.884],
#        [0.999],
#        [0.996],
#        [0.999],
#        [1.   ],
#        [0.998],
#        [1.   ],
#        [0.992],
#        [1.   ],
#        [1.   ],
#        [0.966],
#        [1.   ],
#        [0.729],
#        [0.989],
#        [0.975],
#        [0.936],
#        [1.   ],
#        [0.002],
#        [1.   ],
#        [1.   ],
#        [0.346],
#        [1.   ],
#        [1.   ],
#        [0.002],
#        [0.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.985],
#        [0.998],
#        [0.996],
#        [1.   ],
#        [0.998],
#        [0.962],
#        [0.989],
#        [1.   ],
#        [0.998],
#        [0.995],
#        [0.175],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.994],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.003],
#        [0.986],
#        [0.077],
#        [0.   ],
#        [0.996],
#        [1.   ],
#        [0.967],
#        [0.994],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.165],
#        [0.947],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [0.995],
#        [0.99 ],
#        [0.222],
#        [1.   ],
#        [0.777],
#        [0.995],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.997],
#        [1.   ],
#        [0.998],
#        [0.952],
#        [0.942],
#        [0.996],
#        [1.   ],
#        [0.949],
#        [0.   ],
#        [0.985],
#        [0.999],
#        [0.987],
#        [0.354],
#        [0.933],
#        [1.   ],
#        [0.   ],
#        [1.   ],
#        [0.992],
#        [1.   ],
#        [0.024],
#        [0.996],
#        [1.   ],
#        [0.401],
#        [1.   ],
#        [1.   ],
#        [0.106],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [0.914],
#        [0.003],
#        [1.   ],
#        [0.96 ],
#        [0.984],
#        [0.997],
#        [0.999],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [1.   ],
#        [0.783],
#        [0.   ],
#        [0.999],
#        [0.563],
#        [1.   ],
#        [0.395],
#        [0.981],
#        [0.281],
#        [0.985],
#        [0.003],
#        [0.977],
#        [1.   ],
#        [1.   ],
#        [0.402],
#        [1.   ],
#        [1.   ],
#        [0.057],
#        [0.992],
#        [0.998],
#        [0.971],
#        [0.929],
#        [0.996],
#        [0.   ],
#        [1.   ],
#        [0.996],
#        [0.401],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.024],
#        [1.   ],
#        [0.009],
#        [1.   ],
#        [0.99 ],
#        [0.993],
#        [0.   ],
#        [0.992],
#        [0.01 ],
#        [0.838],
#        [1.   ],
#        [0.994],
#        [0.181],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.949],
#        [0.095],
#        [0.992],
#        [0.996],
#        [1.   ],
#        [1.   ],
#        [0.979],
#        [0.981],
#        [0.   ],
#        [1.   ],
#        [0.013],
#        [0.998],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.996],
#        [0.994],
#        [1.   ],
#        [0.   ],
#        [0.97 ],
#        [0.995],
#        [0.   ],
#        [1.   ],
#        [0.987],
#        [1.   ],
#        [0.101],
#        [1.   ],
#        [0.987],
#        [0.977],
#        [0.997],
#        [0.3  ],
#        [0.263],
#        [0.998],
#        [0.999],
#        [0.995],
#        [0.994],
#        [1.   ],
#        [0.999],
#        [0.086],
#        [1.   ],
#        [0.997],
#        [0.996],
#        [1.   ],
#        [0.918],
#        [0.994],
#        [0.994],
#        [1.   ],
#        [0.997],
#        [0.995],
#        [1.   ],
#        [0.307],
#        [0.   ],
#        [0.997],
#        [1.   ],
#        [1.   ],
#        [0.957],
#        [0.999],
#        [0.049],
#        [1.   ],
#        [0.   ],
#        [0.004],
#        [0.999],
#        [1.   ],
#        [0.966],
#        [0.117],
#        [1.   ],
#        [0.658],
#        [1.   ],
#        [0.974],
#        [0.991],
#        [0.931],
#        [1.   ],
#        [0.001],
#        [0.998],
#        [0.997],
#        [0.206],
#        [1.   ],
#        [0.034],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.655],
#        [1.   ],
#        [0.007],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [1.   ],
#        [0.401],
#        [0.982],
#        [1.   ],
#        [1.   ],
#        [0.986],
#        [1.   ],
#        [0.   ],
#        [0.923],
#        [0.063],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [0.989],
#        [0.003],
#        [0.085],
#        [0.999],
#        [0.085],
#        [0.032],
#        [1.   ],
#        [1.   ],
#        [0.999],
#        [0.875],
#        [1.   ],
#        [0.99 ],
#        [0.952],
#        [0.975],
#        [0.999],
#        [0.915],
#        [0.965],
#        [0.996],
#        [0.99 ],
#        [1.   ],
#        [0.823],
#        [0.998],
#        [0.   ],
#        [0.993],
#        [1.   ],
#        [0.907],
#        [0.955],
#        [1.   ],
#        [0.968],
#        [1.   ],
#        [0.991],
#        [1.   ],
#        [1.   ],
#        [0.025],
#        [0.005],
#        [0.997],
#        [1.   ],
#        [0.365],
#        [0.049],
#        [1.   ],
#        [0.953],
#        [1.   ],
#        [0.991],
#        [0.998],
#        [0.005],
#        [0.   ],
#        [1.   ],
#        [0.995],
#        [1.   ],
#        [0.999],
#        [0.989],
#        [0.   ],
#        [0.969],
#        [0.   ],
#        [0.998],
#        [1.   ],
#        [0.012],
#        [0.998],
#        [0.989],
#        [1.   ],
#        [0.943],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.   ],
#        [0.986],
#        [0.   ],
#        [1.   ],
#        [1.   ],
#        [0.147],
#        [1.   ],
#        [1.   ],
#        [0.006],
#        [0.401],
#        [1.   ],
#        [0.462],
#        [0.949],
#        [0.04 ],
#        [1.   ],
#        [0.925],
#        [1.   ],
#        [1.   ],
#        [0.401],
#        [1.   ],
#        [0.633],
#        [0.936],
#        [0.98 ],
#        [0.007],
#        [0.999],
#        [0.981],
#        [1.   ],
#        [0.972],
#        [0.966],
#        [0.085],
#        [1.   ],
#        [0.999],
#        [1.   ],
#        [1.   ],
#        [0.994],
#        [0.325],
#        [0.999],
#        [0.992],
#        [1.   ],
#        [0.989],
#        [0.998],
#        [0.653],
#        [0.995],
#        [0.214],
#        [0.992],
#        [1.   ],
#        [0.033],
#        [0.99 ],
#        [0.996],
#        [1.   ],
#        [1.   ],
#        [1.   ],
#        [0.004],
#        [0.552],
#        [1.   ],
#        [0.995],
#        [1.   ],
#        [1.   ],
#        [0.917],
#        [1.   ],
#        [0.004],
#        [0.401],
#        [0.999],
#        [0.   ],
#        [0.044],
#        [0.997],
#        [1.   ],
#        [0.993],
#        [0.034],
#        [0.996],
#        [0.998],
#        [1.   ],
#        [0.996],
#        [0.988],
#        [0.999],
#        [0.996],
#        [0.967],
#        [0.997],
#        [0.931],
#        [0.002],
#        [0.997],
#        [0.698],
#        [0.988],
#        [0.994],
#        [0.999],
#        [1.   ],
#        [0.986],
#        [1.   ],
#        [1.   ],
#        [0.998],
#        [1.   ],
#        [0.929],
#        [0.   ],
#        [0.   ],
#        [1.   ],
#        [0.399],
#        [1.   ],
#        [0.   ],
#        [0.001],
#        [1.   ],
#        [0.947],
#        [0.664],
#        [0.728],
#        [0.996],
#        [0.041],
#        [0.385],
#        [1.   ],
#        [0.987],
#        [0.989],
#        [1.   ],
#        [0.999],
#        [1.   ],
#        [0.001],
#        [1.   ]], dtype=float32)

# %%
import seaborn as sns
sns.distplot(j)

# %% [markdown]
# ## Random Forest Classifier

# %%
def rf_classifier(X_train, X_test, y_train, y_test):
    """
    Takes in train-test-split for X,y;
    Runs a randomized search to tune the hyperparameters, 
    then it runs a random forest on the tuned parameters 
    and returns an Accuracy Score and F1 Score.
    """
    forest_clf = RandomForestClassifier(n_estimators = 110, random_state=42)
    forest_clf.fit(X_train,y_train)
    
    random_grid = {'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
                   'max_features': ['auto', 'sqrt'],
                   'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
                   'min_samples_split': [2, 5, 10],
                   'min_samples_leaf': [1, 2, 4],
                   'bootstrap': [True, False]}
    
    rf_random = RandomizedSearchCV(estimator = forest_clf, 
                                   param_distributions = random_grid, 
                                   n_iter = 100, 
                                   cv = 3, 
                                   verbose=2, 
                                   random_state=42, 
                                   n_jobs = -1)
    
    rf_random.fit(X_train, y_train)
    best_rf = rf_random.best_params_
    
    rf_final = RandomForestClassifier(n_estimators=best_rf['n_estimators'],
                                      max_features=best_rf['max_features'],
                                      max_depth=best_rf['max_depth'],
                                      min_samples_split=best_rf['min_samples_split'],
                                      min_samples_leaf=best_rf['min_samples_leaf'],
                                      bootstrap=best_rf['bootstrap'])
    
    rf_final.fit(X_train, y_train)
    y_hat = rf_final.predict(X_test)
    print('Best params:',best_rf,
          '\n\nClassification Report:\n', classification_report(y_test, y_hat), '\n',
          plot_confusion_matrix(rf_final, X_test, y_test, cmap='GnBu', values_format = '.5g'), 
          plt.show())
    return(best_rf)

# %%
best_rf=rf_classifier(X_train_unbalanced, X_test, y_train_unbalanced, y_test)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  4.9min finished
# Best params: {'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 10, 'bootstrap': False}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       196
#            1       0.75      1.00      0.86       604
#
#     accuracy                           0.75       800
#    macro avg       0.38      0.50      0.43       800
# weighted avg       0.57      0.75      0.65       800
#
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f82b41ef400> None

# %% [markdown]
# With unbalanced data: accuracy .75, f1 .86<br>
# Confusion matrix shows ALL class 0 incorrectly scored and almost all class 1 scored correctly.

# %% [markdown]
# ## XG Boost Classifier

# %%
def xgb_classifier(X_train, X_test, y_train, y_test):
    """
    Takes in train-test-split for X,y;
    Runs RandomizedSearchCV and then uses the 
    best parameters to run an XGB model
    and returns a classification report and the best parameters.
    """
    xgb_clf = xgb.XGBClassifier(random_state=42)
    xgb_clf.fit(X_train, y_train)
    
    random_grid = {'max_depth':[3,5,7,10],
                  'min_child_weight':[1,5,10], 
                  'gamma': [0.0,0.1,0.2,0.4],
                  'colsample_bytree':[0.5, 0.7, 0.9],
                 } 
    
    xgb_random = RandomizedSearchCV(estimator = xgb_clf, 
                                    param_distributions = random_grid, 
                                    n_iter = 100, 
                                    cv = 5,
                                    verbose = 2, 
                                    random_state = 42)
    
    xgb_random.fit(X_train, y_train)
    best_xgb = xgb_random.best_params_
    xgb_final = xgb.XGBClassifier(max_depth=best_xgb['max_depth'], 
                                  min_child_weight=best_xgb['min_child_weight'], 
                                  gamma=best_xgb['gamma'],
                                  colsample_bytree=best_xgb['colsample_bytree'],
                                  random_state=42)
    
    xgb_final.fit(X_train, y_train)
    y_hat = xgb_final.predict(X_test)
    print('XGB best params:',best_xgb,
          '\n\nClassification Report:\n', classification_report(y_test, y_hat), '\n',
          plot_confusion_matrix(xgb_final, X_test, y_test, cmap='GnBu', values_format = '.5g'), 
          plt.show())
    return(best_xgb)

# %%
best_xgb=xgb_classifier(X_train_unbalanced, X_test, y_train_unbalanced, y_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=3, gamma=0.4, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.5s
# [CV] min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.6s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.6s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.6s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.6s
# [CV] min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.9, total=   0.6s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.2, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.2, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.2, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.1, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=7, gamma=0.2, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=7, gamma=0.4, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=10, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# ...
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=7, gamma=0.4, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.5s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7
# [CV]  min_child_weight=5, max_depth=10, gamma=0.1, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=5, gamma=0.4, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=10, max_depth=10, gamma=0.2, colsample_bytree=0.7, total=   0.4s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=5, gamma=0.2, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=10, gamma=0.2, colsample_bytree=0.9, total=   0.5s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=5, max_depth=3, gamma=0.1, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.1, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=7, gamma=0.1, colsample_bytree=0.9, total=   0.4s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=5, gamma=0.0, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=5, gamma=0.1, colsample_bytree=0.5, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.4, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.7, total=   0.1s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=1, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=1, max_depth=7, gamma=0.0, colsample_bytree=0.5, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=5, gamma=0.0, colsample_bytree=0.9, total=   0.3s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5
# [CV]  min_child_weight=10, max_depth=3, gamma=0.0, colsample_bytree=0.5, total=   0.1s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [CV] min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9
# [CV]  min_child_weight=10, max_depth=3, gamma=0.2, colsample_bytree=0.9, total=   0.2s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:  2.2min finished
# XGB best params: {'min_child_weight': 5, 'max_depth': 10, 'gamma': 0.1, 'colsample_bytree': 0.7}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       196
#            1       0.75      0.99      0.86       604
#
#     accuracy                           0.75       800
#    macro avg       0.38      0.50      0.43       800
# weighted avg       0.57      0.75      0.65       800
#
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f82b41a02e8> None

# %% [markdown]
# XG Boost returned an accuracy of 74% and f1-score for class 1 of .85. BUT, the confidence matrix shows that it's predicting most all of the class 1 labels correctly, but most all of the class 0 labels incorrectly.
#
# <br>Will re-try on the unbalanced data:
# <br> Accuracy of 75% and f1 for class 1 of .86 with unbalanced data.

# %% [markdown]
# # Create Stacked Model
#
# https://towardsdatascience.com/a-practical-guide-to-stacking-using-scikit-learn-91e8d021863d

# %%
def nn_classifier():
    """Neural network reformed for scikit-learn"""
    tf.random.set_random_seed(7)
    model = Sequential()
    model.add(Dense(16, input_dim=605, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(8, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(8, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    recall = km.binary_recall(label=0)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', recall])
    return model

# %%
NN_clf=KerasClassifier(build_fn=nn_classifier, epochs=100, batch_size= 32, validation_split=0.2)
NN_clf._estimator_type = "classifier"

LR_clf=LogisticRegression(solver=best_lr['solver'],
                          penalty=best_lr['penalty'],
                          C=best_lr['C'], 
                          random_state=42)

RF_clf=RandomForestClassifier(n_estimators=best_rf['n_estimators'],
                              max_features=best_rf['max_features'],
                              max_depth=best_rf['max_depth'],
                              min_samples_split=best_rf['min_samples_split'],
                              min_samples_leaf=best_rf['min_samples_leaf'],
                              bootstrap=best_rf['bootstrap'], 
                              random_state=42)

XG_clf=xgb.XGBClassifier(max_depth=best_xgb['max_depth'], 
                         min_child_weight=best_xgb['min_child_weight'], 
                         gamma=best_xgb['gamma'],
                         colsample_bytree=best_xgb['colsample_bytree'],
                         random_state=42)
    
estimators = [('LR', LR_clf),  ('RF', RF_clf), ('XG', XG_clf)] # removed ('NN', NN_clf),

clf=StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# %%
clf.fit(X_train_unbalanced, y_train_unbalanced)
y_hat_stacked = clf.predict(X_test)
print('Classification Report:\n', classification_report(y_test, y_hat_stacked),'\n',
      plot_confusion_matrix(clf, X_test, y_test, cmap='GnBu', values_format = '.5g'), 
      plt.show())
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       196
#            1       0.76      1.00      0.86       604
#
#     accuracy                           0.76       800
#    macro avg       0.38      0.50      0.43       800
# weighted avg       0.57      0.76      0.65       800
#
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f82b2d8ff98> None

# %% [markdown]
# **Balanced Data // Scores are Mean Accuracy:**<br>
# Stacking model score: 0.714 - no tuning the RF classifier <br>
# Stacking model score: 0.719 - tuned RF classifier <br>
# Stacking model score: 0.715 - added XGBoost classifier <br>
# ---- After adding Classification Report:<br>
# **Balanced Data / Dummy Classifier:**<br>
# Accuracy 0.49, f1 0.59 for Class 1 <br>
# **Balanced Data / Stacking Classifier:**<br>
# Accuracy 0.73, f1 0.84 for Class 1 <br>
# **Unbalanced Data / Dummy Classifier:**<br>
# Accuracy 0.49, f1 0.59 for Class 1 <br>
# **Unbalanced Data / Stacking Classifier -- removed NN since loss diverged:**<br>
# Accuracy 0.76, f1 0.86 for Class 1 <br>
# Results are much better with both unbalanced data and no neural network; should try with balanced and no NN.
