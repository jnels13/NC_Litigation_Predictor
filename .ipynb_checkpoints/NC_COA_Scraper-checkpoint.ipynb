# %% [markdown]
# ## NC Court of Appeals Scraper
#
# This notebook will scrape the NC Court of Appeals web site

# %%
from bs4 import BeautifulSoup
import requests
import pickle

# %%
# Make a get request to retrieve the court of appeals' page
html_page = requests.get('https://appellate.nccourts.org/opinion-filings/?c=coa&year=2020') 
# Pass the page contents for parsing
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# ...

# %%
titles = soup.findAll('span', class_="title")
titles[0]
# Out:
# <span class="title" onclick='viewOpinion("http://appellate.nccourts.org/opinions/?c=2&amp;pdf=39484")'>Blue v. Thakurdeo Michael Bhiro, PA <strong></strong> (20-159 - Published)
# 					</span>

# %%
titles[0].attrs['onclick']
# Out:
# 'viewOpinion("http://appellate.nccourts.org/opinions/?c=2&pdf=39484")'

# %%
titles[0].attrs['onclick'].strip('viewOpinion(\"').strip('\")')
# Out:
# 'http://appellate.nccourts.org/opinions/?c=2&pdf=39484'

# %%
page_links = [titles.attrs['onclick'].strip('viewOpinion(\"').strip('\")') for titles in soup.findAll('span', class_='title')]

# %%
len(page_links)
# Out:
# 900

# %% [markdown]
# The COA's web page contains entries for 1998-2020.  Create a function that appends all

# %%
# SCRAPE ALL PDF LINKS
all_links = []
for i in range(1998,2021,1):
    cur_year = 'https://appellate.nccourts.org/opinion-filings/?c=coa&year={}'.format(i)
    html_page = requests.get(cur_year)
    soup = BeautifulSoup(html_page.content, 'html.parser') 
    page_links = [titles.attrs['onclick'].strip('viewOpinion(\"').strip('\")') for titles in soup.findAll('span', class_='title')]
    all_links += page_links

# %%
len(all_links)
# Out:
# 28862

# %%
set(all_links) #delete any possible duplicates
len(all_links)
list(all_links)
# Out:
# ['http://appellate.nccourts.org/opinions/?c=2&pdf=14789',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=15001',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14940',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14910',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14676',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14855',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14974',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14779',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14106',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=13980',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=15021',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=15088',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14587',
#  'http://appellate.nccourts.org/opinions/?c=1&pdf=8233',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=14773',
#  'http://appellate.nccourts.org/opinions/?c=2&pdf=15084',
# ...

# %%
#SAVE PDF ADDRESSES TO DATA FILE
with open('pdf_addresses.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(all_links, filehandle)
