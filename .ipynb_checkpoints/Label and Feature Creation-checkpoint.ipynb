# %% [markdown]
# # Label and Feature Creation
# In this notebook, I will import the single-column DataFrame of appellate opinions and create columns with labels and features.
# ## Contents:
# <ul>
# <li>0. Import Libraries
# <li>1. Clean up opinions
# <ul><li>A. Remove page numbers from opinions
#     <li>B. Remove Supreme Court case
#     <li>C. Drop Dissents
#     </ul>
# <li>2. Add file numbers
# <li>3. Create Labels section
# <ul><li>A. Create function and apply to DataFrame
# <li>B. Clean up, combine, and drop columns
#     <li>C. Address reversing-denials or affirming-denials </ul>
# <li>4. Create case-type column
# <li>5. Extract Trial Court Judge
# <li>6. Extract County
# <li>7. Export DataFrame with Features
# <li>8. EDA Visualizations - TBD
# </ul>
#
# Dataset Reduction:<br>
# 1052 rows dropped for not fitting the affirmed/reversed criteria (errors, affirmed in part, appeals dismissed, etc.)<br>
# 38 rows dropped for not conforming to a reasonable case type or being too short to have a reasonable effect.<br>
# 84 rows dropped from the Supreme Court, reviewing underlying decisions (lacking the features of court of appeals cases)<br>
# 49 rows dropped from the trial_judge extraction function which were either administrative or multiple orders.<br>
# 08 rows dropped from the county extraction section <br>

# %% [markdown]
# ## 0. Import Libraries and DataFrame

# %%
import io
import re
import pandas as pd
import pickle
import operator

# import nltk
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('punkt')
# from nltk.corpus import stopwords
# from nltk import word_tokenize
# from nltk.stem.wordnet import WordNetLemmatizer
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

# %%
# Open the dataframe
infile = open('ProjectData/df_clean.data', 'rb')
df = pickle.load(infile)
infile.close()

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3922 entries, 0 to 3921
# Data columns (total 1 columns):
# Opinion    3922 non-null object
# dtypes: object(1)
# memory usage: 30.8+ KB
# (None,                                              Opinion
#  0   an unpublished opinion of the north carolina ...
#  1  no. coa11-246 north carolina court of appeals ...
#  2  no. coa08-347 north carolina court of appeals ...
#  3  michael harrison gregory and wife, vivian greg...
#  4  atlantic contracting and material company, inc...)

# %% [markdown]
# ## 1. Remove Page Numbers & Supreme Court Cases
#
# ### A. Remove Page Numbers
# Page numbers (-1-) appear throughout the corpus and complicated some of the following functions.  Accordingly, they're removed here.

# %%
def remove_page_nums(string_):
    """
    A function to remove page numbers from a given string
    Page numbers must be the format "-##-"
    """
    new_string = re.sub(" -\d+- ", " ", string_)
    return(new_string)

# %%
no_page_list = []
for i in range(len(df.Opinion)):
    x = remove_page_nums(df.Opinion[i])
    no_page_list.append(x)
    
df["Opinion"] = pd.Series(no_page_list).values

# %%
df.head()
# Out:
#                                              Opinion
# 0   an unpublished opinion of the north carolina ...
# 1  no. coa11-246 north carolina court of appeals ...
# 2  no. coa08-347 north carolina court of appeals ...
# 3  michael harrison gregory and wife, vivian greg...
# 4  atlantic contracting and material company, inc...

# %% [markdown]
# ### Fix Irish Names (O'xxx)

# %%
def lose_the_apostrophe(string_):
    """
    A function to remove apostrophes from Irish names; 
    The majority of the tokenization will be performed
    on the following dataframe.
    """
    new_string = re.sub(" o’|o'", " o", string_)
    
    return(new_string)

# %%
no_apostrophes = []
for i in range(len(df.Opinion)):
    x = lose_the_apostrophe(df.Opinion[i])
    no_apostrophes.append(x)
    
df["Opinion"] = pd.Series(no_apostrophes).values

# %% [markdown]
# ### B. Remove Supreme Court Cases (that review Court of Appeals cases)
# These cases review the Court of Appeals' decisions; they don't typically include features the same way that the Court of Appeals does, and their rulings are usually affecting the Court of Appeals (which may be the opposite of the underlying case). Accordingly, they should be dropped for this project.

# %%
df['SCT'] = 0

# %%
# capture file number into new column
def drop_SCT(string_):
    sct_yes = re.search("in the supreme court of north carolina",string_[:50])
    if sct_yes == None:
        return(0)
    else:
        return(1)

# %%
df['SCT'] = df.Opinion.map(lambda x: drop_SCT(x))
len(df.loc[df['SCT'] == 1])
# Out:
# 84

# %%
# drop supreme court cases
df.drop(list(df.loc[df['SCT'] == 1].index), inplace=True)
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### C. Trim Dissents, Because They are Not Relevant to the Function
#
# #Dissents follow the opinion, when one of the three appellate judges doesn't agree; they may trigger further appeal, but they are not law, and may skew results, so they should be dropped.
#
# #### Exploration of opinions containing the phrase "dissenting"

# %%
dissents = df.loc[df['Opinion'].str.contains("dissenting")]

# %%
dissents.head()
# Out:
#                                               Opinion  SCT
# 13  energy investors fund, l.p., inc., kvaerner as...    0
# 22   in the court of appeals of north carolina no....    0
# 27  cecelia l. ford, administrator of the estate o...    0
# 35  carolina place joint venture, plaintiff-appell...    0
# 45  christian emerson dysart and mildred maxwell d...    0

# %% [markdown]
# Review example opinions containing the word "dissent" to see which need to be dropped:</p>
# Verbiage: (Y=actual dissent N=not a dissent)<br>
# Y judge horton dissenting<br>
# Y judge wynn dissents. ... wynn, judge, dissenting.<br>
# Y tyson, judge dissenting.<br>
# Y judge tyson concurs in part, dissents in part.<br>
# Y calabria, judge, dissenting. // therefore, i respectfully dissent.<br>
# Y justice martin dissenting. -- Conflicts w below -- maybe eliminate first 2000 chars? <br>
# Y === wynn, judge dissenting.<br>
# Y - elmore, judge, dissenting.<br>
# Y. martin, chief judge, concurring in part, dissenting in part. - But later<br>
# Y = campbell, judge, dissenting. i respectfully dissent <br>
# Y == thomas, judge, dissenting.<br>
# Y judge dillon dissents in a separate opinion. - 12,600 chars into 17,000 char opi<br>
# <br>
# N piazza v. kirkbride tyson, j., concurring in part, dissenting in part.<br>
# N souter, j., dissenting (cit<br>
# N r. justice martin dissenting. justice brady dissenting. a -- too early  (913 chars in, 80,000 char opinion)<br>
# N (greene, j. dissenting) - case citation<br>
# N . judge elmore dissenting. -- too early, 2400 chars in to 28,000 char opinion<br>
# N m. chief judge martin concurring in part and dissenting in part. - 2731 chars into 29,000 char opinion<br>
# N (hudson, j., dissenting) <br>
# N   1715 chars into 23,000 char opinion<br>
# ------ never the (j., dissenting)<br>
# <br>
# Pseudocode:<br>
# IF ends with "judges /2 and /2 concur." (not concurs) - there isn't a dissent (one of the two would be dissenting). <br>
# ELSE if after the first 3,000 chars, of the opinion:<br>
#     judge /4 (dissent*)<br>
#
# #### Trimming-Dissents Function Creation and Revision
# Created the below function following the preceding review; ran the function and reviewed the trimmed opinions for correctness (i.e., was something more or less than a dissent trimmed from the opinion).  The function was updated to put (judge|justice) in parens and to make the verb "dissents" instead of the noun "dissent", which was pulling references to other dissents.

# %%
def trim_dissents(opinion):
    global trimmed_dissents
    if re.search("(dissent)", opinion):
        if re.search("judges\W+(?:\w+\W+){0,5}?concur\b", opinion):
            return()  
        else:
            try:
                y = re.search("(?:(judge|justice)\W+(?:\w+\W+){0,6}?dissents)", opinion[3000:])
                cut_off_point = y.start()
                opinion2 = opinion[:(cut_off_point+3000)]
                trimmed_dissents += 1
                return(opinion2)
            except:
                return(opinion)
    else:
        return(opinion)

# %%
# Drop dissents
trimmed_dissents = 0
new_opinions = []
for i in range(len(df.Opinion)):
    x = trim_dissents(df.Opinion[i])
    new_opinions.append(x)
    
# Replate opinions with trimmed opinions
df["Opinion"] = pd.Series(new_opinions).values

# %% [markdown]
# ## 2. Creating New Columns for the File Numbers and Years
# The file numbers should have no predictive value; this section is more for EDA/visualizations than practical.

# %%
# capture file number into new column
def yr_filed(string_):
    try:
        year_filed = re.search("filed:? ?\d+ ?\D+ (\d+)",string_)
        return year_filed.group(1)
    except:
        return(0)

# %%
years = []
for i in range(len(df)):
    x = yr_filed(df.Opinion[i])
    years.append(x)

df["Year_Filed"] = pd.Series(years).values.astype(int)

# %%
df.describe()
# Out:
#           SCT   Year_Filed
# count  3838.0  3838.000000
# mean      0.0  2006.852006
# std       0.0    55.212325
# min       0.0     0.000000
# 25%       0.0  2004.000000
# 50%       0.0  2008.000000
# 75%       0.0  2013.000000
# max       0.0  2020.000000

# %%
df.loc[df.Year_Filed < 1990]
# Out:
#                                                 Opinion  SCT  Year_Filed
# 55    parkwood association, plaintiff v. capital hea...    0        1532
# 56    franklin r. dewitt v. eveready battery co., in...    0           0
# 585   luther lee key, plaintiff v. barbara m. burche...    0         199
# 3380  correction: 6/10/99 - please add to attorney l...    0           0

# %%
# Handling errors in the data manually
df.Year_Filed.replace([0,199,1532], 1999, inplace=True)

# %%
df.describe()
# Out:
#           SCT   Year_Filed
# count  3838.0  3838.000000
# mean      0.0  2008.484367
# std       0.0     5.997362
# min       0.0  1998.000000
# 25%       0.0  2004.000000
# 50%       0.0  2008.000000
# 75%       0.0  2013.000000
# max       0.0  2020.000000

# %%
# capture file number into new column
def coa(string_):
    try:
        pat_coa_number = re.search("no.? ?coa.? ?(\d{2}-\d{1,5})",string_)
        return pat_coa_number.group(1)
    except:
        return('00-000')

# %%
coa_numbers = []
for i in range(len(df)):
    x = coa(df.Opinion[i])
    coa_numbers.append(x)

df["File_Numbers"] = pd.Series(coa_numbers).values

# %%
df.head(5)
# Out:
#                                              Opinion  SCT  Year_Filed File_Numbers
# 0   an unpublished opinion of the north carolina ...    0        2020       19-563
# 1  no. coa11-246 north carolina court of appeals ...    0        2012       11-246
# 2  no. coa08-347 north carolina court of appeals ...    0        2009       08-347
# 3  michael harrison gregory and wife, vivian greg...    0        2006       05-885
# 4  atlantic contracting and material company, inc...    0        2003      02-1087

# %% [markdown]
# ## 3. Creating the Labels (Affirmed, Reversed, etc.)
#
# The labels were created using the regex patterns below. The ultimate fuction below was created over many iterations. Initially, there were approximately 300 errors; the model was tweaked to reduce errors while maintaining reliability. Ultimately, 25 rows were dropped as errors because the cases were not beneficial to the model (i.e., they did not include a relevant summary judgment decision, the opinion on summary judgment was entwined with other components, etc.); 454 "affirmed-in-part" rows were dropped since they're not the binary outcome needed; and 408 dismissals were dropped since they don't have a usable outcome.

# %% [markdown]
# ### A. Functions to Assign and Apply Labels to the DataFrame

# %%
def labels(string_):
    """
    This function will extract the outcome from a given string (opinion).
    Each of the 'try' statements extracts the labels with decreasing 
    degrees of confidence (first by the one-word sentence, then within
    10 words of the statement regarding concurrence, typically near the 
    end of the opinion; then clipping the last 150 chars. of the opinion 
    and looking for the associated label-words, and finally looking for 
    label-words within 5-10 words of the often-occurring phrase, 'for the
    reasons set forth above'). This try/except format recognizes the 
    hierarchy from the most likely correct match to the lesser likely 
    correct matches. The form follows the Python EAFP principle.
    """
    try:
        try:
            try:
                try:  #this level has the highest confidence of getting an accurate label, based upon review of opinions (a single-word sentence)
                    labels = re.search("\.. ?(affirmed?)\.|\.?(reversed?)\.|(affirmed in part)|\.?(dismissed)\.",string_)
                    x = labels.group(1)
                    y = labels.group(2)
                    z = labels.group(3)
                    w = labels.group(4)
                    not_none = [x,y,z]
                    a = [i for i in not_none if i != None]
                    return a[0]
                except:  # slightly less confidence; looks for outcome word within 10 words of "concur", which frequently is at the end of a unanymous opinion
                    labels = re.search("(?:concurs?\W+(?:\w+\W+){0,40}?((affirmed in part)|reversed|affirmed|dismissed|no error|vacated)|((affirmed in part)|affirmed|reversed|dismissed|no error|vacated)\W+(?:\w+\W+){0,40}?concurs?)", string_)
                    #print("Group 0:", labels.group(0), "\nGroup 1:", labels.group(1), "\nGroup 2:", labels.group(2), "\nGroup 3:", labels.group(3), "\nGroup 4:", labels.group(4))
                    x = labels2.group(1)
                    y = labels2.group(2)
                    z = labels2.group(3)
                    w = labels2.group(4)
                    not_none = [x,y,z,w]
                    a = [i for i in not_none if i != None]
                    #print("This is resulting list a:", a)
                    return a[0]
            except: #slightly less confidence; if both of the previous methods fail, this clips the last 150 chars of the opinion for any of the outcome words
                clip = string_[-150:]
    #             print(clip)
                labels3 = re.search("('affirmed in part'|reversed|affirmed|dismissed|'affirm in part'|affirm|reverse|dismiss|improvidently allowed)",clip)
                return labels3.group(0)
        except: 
            labels4 = re.search("(?:reasons set forth?\W+(?:\w+\W+){0,5}?((affirm in part)|reverse|affirm|dismiss|no error|vacated?)|((affirm in part)|affirm|reversed?|dismiss|no error|vacated?)\W+(?:\w+\W+){0,10}?reasons set forth?)", string_)
            #print("Group 0:", labels.group(0), "\nGroup 1:", labels.group(1), "\nGroup 2:", labels.group(2), "\nGroup 3:", labels.group(3), "\nGroup 4:", labels.group(4))
            x = labels4.group(1)
            y = labels4.group(2)
            z = labels4.group(3)
            w = labels4.group(4)
            not_none = [x,y,z,w]
            a = [i for i in not_none if i != None]
            #print("This is resulting list a:", a)
            return a[0]
    except:
        return('error')

# %%
# Test Cell 
labels(df.Opinion[2])
# Out:
# 'affirmed'

# %%
# Apply labels to the DataFrame
labels_list = []
for i in range(len(df.Opinion)):
    x = labels(df.Opinion[i])
    labels_list.append(x)

df["Result"] = pd.Series(labels_list).values

# %%
df.Result.value_counts()
# Out:
# affirmed                 2021
# reversed                  558
# affirmed in part          392
# dismissed                 232
# error                     200
# dismiss                   190
# reverse                   162
# affirm                     75
# improvidently allowed       6
# no error                    1
# vacate                      1
# Name: Result, dtype: int64

# %% [markdown]
# ### B. Combine Similar Terms and Drop Rows Irrelevant to the Outcome

# %%
df['Result'].replace(['reverse','affirm', 'dismiss','no error', 'vacated', 'improvidently allowed'],
                     ['reversed','affirmed','dismissed', 'affirmed', 'reversed', 'dismissed'], inplace=True)

# The model will treat 'no error' as 'affirmed' and 'vacated' as 'reversed'

# %%
df.Result.value_counts()
# Out:
# affirmed            2097
# reversed             720
# dismissed            428
# affirmed in part     392
# error                200
# vacate                 1
# Name: Result, dtype: int64

# %%
# Drop rows with 'error', 'dismissed', and 'affirmed in part' -- see section header, above
drop_list1 = df.loc[df['Result'] == 'error']
drop_list2 = df.loc[df['Result'] == 'affirmed in part']
drop_list3 = df.loc[df['Result'] == 'dismissed']
drop_list4 = df.loc[df['Result'] == 'vacate']

# %%
drop_list = list(drop_list1.index)+list(drop_list2.index)+list(drop_list3.index)+list(drop_list4.index)

# %%
df.drop(drop_list, axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.Result.value_counts()
# Out:
# affirmed    2097
# reversed     720
# Name: Result, dtype: int64

# %% [markdown]
# ### C. Ensure Labels Have the Same Effect Throughout the DataFrame (Substantial Right Appeals)

# %%
def substantial_right(string_):
    """ 
    I have been treating the label "affirm" as affirming the grant 
    of a summary judgment motion, and "reverse" as reversing the grant 
    of the motion, because it is much more common for the court of appeals 
    to address GRANTS of summary judgment. Much more rarely, they will 
    review a motion denying summary judgment, and the above functions will 
    have the opposite label than intended. This function will take a string, 
    review whether it contains the key words "substantial right," and then 
    analyze the language of the opinion to see if the opinion affirms or 
    reverses the DENIAL of summary judgment. If it does, it will return a
    '1', and if not, a '0'. This can be used later as a switch to flip the 
    label assigned above.
    """
    # Screen for the keword 'substantial right'
    if string_.count("substantial right") > 0:
        x = re.search("(?:(affirm|reverse?)\W+(?:\w+\W+){0,5}?denial)", string_)
        try:
            x.group(0)
            return(1)
        except:
            return(0)

# %%
substantial_right_list = []
for i in range(len(df.Opinion)):
    x = substantial_right(df.Opinion[i])
    substantial_right_list.append(x)

df["sub_right"] = pd.Series(substantial_right_list).values

# %%
df.loc[df['sub_right'] == 1]
# Out:
#                                                 Opinion  SCT  Year_Filed File_Numbers    Result  \
# 336   estate of erik dominic williams, by and throug...    0        2011       10-491  affirmed
# 357   no. coa11-1466 north carolina court of appeals...    0        2012      11-1466  reversed
# 441   estate of vera hewett, et al, plaintiffs, v. c...    0        2009      08-1071  reversed
# 604   james l. pierson, kathy l. pierson, lincoln m....    0        2000      99-1333  affirmed
# 765   mitchell, brewer, richardson, adams, burge & b...    0        2011      09-1020  reversed
# 869   nello l. teer company, inc., plaintiff, v. jon...    0        2007       06-340  reversed
# 938    in the court of appeals of north carolina no....    0        2018       16-908  reversed
# 957   an unpublished opinion of the north carolina c...    0        2004      02-1610  affirmed
# 980   wilson myers, administrator of the estate of t...    0        2008       07-285  affirmed
# 995   michael g. staley and melody h. staley, plaint...    0        1999      98-1293  reversed
# 1132  tiber holding corporation, regis insurance com...    0        2005      04-1184  affirmed
# 1197  lennie and bonnie hamby, plaintiffs, v. profil...    0        2009       08-942  affirmed
# 1321  teresa h. satorre, sharon o. lee, theresa k. p...    0        2004       03-648  reversed
# 1449  an unpublished opinion of the north carolina c...    0        2015       14-811  affirmed
# 1534  no. coa02-423 north carolina court of appeals ...    0        2003       02-423  reversed
# 1632   an unpublished opinion of the north carolina ...    0        2019      18-1207  reversed
# 1643  jon-paul craig, by his mother and next friend,...    0        2007        07-80  reversed
# 1692   in the court of appeals of north carolina no....    0        2019       18-478  affirmed
# 1710   in the court of appeals of north carolina no....    0        2017       16-776  reversed
# 1804  josephine williams, administratrix of the esta...    0        2004      03-1624  affirmed
# 1969  keith brent vest v. michael f. easley, north c...    0        2001       00-635  reversed
# 2001   in the court of appeals of north carolina no....    0        2016       15-751  reversed
# 2086  thomas william hill, plaintiff, v. bobby medfo...    0        2003       02-956  affirmed
# 2176  johnston health care center, l.l.c. petitioner...    0        2000       99-129  affirmed
# 2432  anne h. craig v. the asheville city board of e...    0        2001       00-175  affirmed
# 2485  an unpublished opinion of the north carolina c...    0        2010       09-315  affirmed
# 2612   an unpublished opinion of the north carolina ...    0        2019       18-197  reversed
# 2613  no. coa08-801 north carolina court of appeals ...    0        2009       08-801  affirmed
# 2625  an unpublished opinion of the north carolina c...    0        2013      12-1490  affirmed
# 2737  sherri b. blaylock, as guardian ad litem for h...    0        2009       00-000  affirmed
# 2811  1 bruce-terminix co. v. zurich ins. co., 130 n...    0        2008      07-1260  affirmed
#
#       sub_right
# 336         1.0
# 357         1.0
# 441         1.0
# 604         1.0
# 765         1.0
# 869         1.0
# 938         1.0
# 957         1.0
# 980         1.0
# 995         1.0
# 1132        1.0
# 1197        1.0
# 1321        1.0
# 1449        1.0
# 1534        1.0
# 1632        1.0
# 1643        1.0
# 1692        1.0
# 1710        1.0
# 1804        1.0
# 1969        1.0
# 2001        1.0
# 2086        1.0
# 2176        1.0
# 2432        1.0
# 2485        1.0
# 2612        1.0
# 2613        1.0
# 2625        1.0
# 2737        1.0
# 2811        1.0

# %% [markdown]
# Review of the foregoing cases had so many with mixed issues that it will probably be better to drop all rows.

# %%
indexes_to_drop = df.index[df['sub_right'] == 1].tolist()
df.drop(indexes_to_drop, inplace=True)

df.drop(['sub_right'], axis=1, inplace=True)

df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## 4. Create Case-Type Feature By Sorting With Keywords
#
# I created a simple sorting function which takes a dictionary of case types with associated keywords, and then it generates a popularity count of the various keywords, returning the highest-ranking case type for a given opinion. The dictionary was revised over many iterations and reviews; for instance, some words were not unique, were misleading, or needed leading/trailing spaces.

# %%
# This dictionary contains types of law with associated, typically unique keywords
case_type_dict = {'premises':['premises', 'attractive nuisance', 'dangerous condition', 'slip and fall',
                              'defective condition', 'dog bite', 'landowner', 'vicious propensity',
                              'defective or unsafe condition', 'unsafe condition'], 
                  'products':['negligently manufactured', 'negligent manufacture', 'negligently designed',
                              'negligent design', 'manufacturing defect', 'products liability',
                              'product liability', 'ordinary use', 'product at issue', 'defective good'],
                  'car_crash':['collision', 'vehicle', 'motorist', 'other driver'], 
                  'corporate':['shareholder', 'bylaw', 'articles of incorporation', 'derivative', 
                               'corporate meetings', 'corporate books', 'annual meeting', 
                               'financial statements'],
                  'construction':['building defect', 'water intrusion', 'construction defect', 'building code',
                                  'subcontractor', 'construction industry'], 
                  'contract':[' formation', 'recission', 'specific performance', 'incidental damages',
                              'consequential damages', 'statute of frauds', 'complex business',
                              'contractual relationship', 'contract law', 'plain and unambiguous',
                              'promissory note', 'clinical privileges', 'agreement in effect', 
                              'breach of contract', 'terms of the agreement', 'default on the account',
                              'joint venture', 'credit account', 'payment of the debt', 'consignor',
                              'cosignee', 'oral contract', 'doctrine of necessaries', 'sold and delivered',
                              'defaulted on the loan', 'line of credit', 'credit card account', 
                              'security interest', 'past due and owing', 'contract price', 'guaranty agreement',
                              'contract to purchase', 'fdcpa'], 
                  'defamation':['libel', 'slander', 'defamatory', 'defamation'],
                  'employment':['wrongful discharge', 'discrimination', 'retaliation', 'retaliatory',
                                'retaliatory employment discrimination act', 'discriminatory',
                                'state personnel', 'state retirement plan', 'pay policy', 'salary',
                                'at-will employee', 'reinstatement', 'h-2a', 'wage and hour', 'fmla',
                                'disability benefits', 'employer-employee', 'wage laws'],
                  'estates':['intestate', 'probate', 'revocable trust', 'irrevocable trust', 'testator',
                             'holographic', 'residue', 'testate', 'partition and sale', 'undivided interest',
                             'executor', 'executrix', 'beneficiary', 'will conveying'],
                  'family_law':['divorce', 'custody', 'maintenance', 'child support', 'separation agreement',
                               'prenuptial', 'postnuptial', 'premarital', 'marital home', 'parental rights',
                               'alienation of affection', 'legally separated', 'marriage ceremony'], 
                  'fraud_udtpa':['unfair and deceptive', 'unfair or deceptive', 'chapter 75', 'fraud',
                                 'calculated to deceive'],
                  'governmental':['sovereign immunity', 'official capacity', 'governmental immunity', 
                                  'certificate of need', 'incarcerated', 'permit application', 
                                  'property tax commission', 'local school administrative unit',
                                  'public duty doctrine', 'malicious prosecution', 'inmate', 'wastewater',
                                  'separation of powers', 'secretary of revenue', 'school boards association',
                                  'department of environment and natural resources', 'municipal corporation',
                                  'local government retirement system'],
                  'insurance':['policy exclusion', 'insured party', 'coverage under the policy',
                               'insurance coverage'],
                  'landlord_tenant':['lease', 'landlord', 'security deposit', ' rent ', 'chapter 42', 'tenant'], 
                  'med_mal':['medical malpractice','health care profession', 'same or similar community', 
                             'rule 9(j)', 'rule 702(b)', 'continuing course of treatment', 'skilled nursing',
                             'care and treatment rendered'], 
                  'property':['easement', 'fee simple', 'tenants in common', 'joint tenants', 'nuisance', 
                             'eminent domain', 'escheat', 'replevin', 'zoning', 'mortgage', 'foreclosure',
                             'restriction agreement', 'reforming the deed', 'covenants and restrictions',
                             'property boundary', 'declaration of covenants', 'homeowners association',
                             'trespass to land', 'deed of trust', 'restrictive covenant', 'executed the deed',
                             'board of adjustment', 'improvement to land', 'quiet title', 'convey the property',
                             'blasting'], 
                  'workers_comp':['workers compensation', 'worker\'s compensation', 'fela',
                                  'workers\' compensation', 'workmen\'s compensation'],
                  'wrongful_death':['wrongful death']}

# 'dram_shop':['dram shop'] -- removed, only 2 that were not superseded by "car crash"

# %%
def case_type_sorter(dict_of_keywords, string):
    """ 
    This function takes a dictionary of case types and associated 
    keywords, assigns points for the frequency of the keywords
    of a given case type, and returns the case type with the highest
    number of points, as well as a confidence measure.  The dict_of_keywords 
    should be a dictionary of case-type keys and keyword values; the string 
    should be a single string.
    """
    counter_dict = {}

    # Iterate through dictionary, counting frequency of each keyword in the string/Opinion
    for key, values in dict_of_keywords.items():
        counter_dict[key] = 0
        for value in values:
            count = string.count(value)
            existing_count = counter_dict[key]
            counter_dict[key] = count + existing_count
    
    # Get total points for all keywords
    values = counter_dict.values()
    total_count = sum(values)
    
    # Ensure that if no case_types are matched, the type returned is 'other'
    if total_count > 0:
        likely_case_type = max(counter_dict.items(), key=operator.itemgetter(1))[0]
    else:
        likely_case_type = 'other'
    
    # Return a confidence ratio (points of most likely type / all points )
    try:
        confidence = str(round((counter_dict[likely_case_type]/total_count)*100,2))+'%'
    except:
        confidence = 'n/a'
    
    return likely_case_type, confidence

# %%
# Copy of the above function for case-by-case review
def case_type_test_sorter(dict_of_keywords, string):
    """ 
    This is a copy of the case_type_sorter function for case-by-case review
    """
    counter_dict = {}

    # Iterate through dictionary, counting frequency of each keyword in the string/Opinion
    for key, values in dict_of_keywords.items():
        counter_dict[key] = 0
        for value in values:
            count = string.count(value)
            existing_count = counter_dict[key]
            counter_dict[key] = count + existing_count
            
    return counter_dict

# %%
# Apply case_type and confidence level columns to the DataFrame

case_type_list = []
case_type_confidence = []
for i in range(len(df.Opinion)):
    y,z = case_type_sorter(case_type_dict, df.Opinion[i])
    case_type_list.append(y)
    case_type_confidence.append(z)

df["Case_Type"] = pd.Series(case_type_list).values
df["Case_Type_Confidence"] = pd.Series(case_type_confidence).values

# %%
one = df.loc[(df['Case_Type'] == 'other') & (df.Opinion.str.len() > 1350)]

# %%
#remaining "other" case types and cases shorter than 1350 characters (lacking any type information)
len(one)
# Out:
# 39

# %%
# Test function to review cases and diagnose issues (ultimately to update the case_type_dict)
try:
    test_cell = int(input("Index to Test:"))
    print(case_type_sorter(case_type_dict, df.Opinion[test_cell]),
          '\n\n', case_type_test_sorter(case_type_dict, df.Opinion[test_cell]),
          '\n\n', df.Opinion[test_cell])
except:
    print("Please enter an index to review:")
# Out:
# Index to Test:
# Please enter an index to review:

# %%
drop_list_others = list(one.index)
df.drop(drop_list_others, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.Case_Type.value_counts()
# Out:
# property           369
# contract           333
# car_crash          318
# fraud_udtpa        275
# governmental       246
# landlord_tenant    229
# family_law         187
# premises           162
# employment         144
# estates            125
# med_mal             88
# corporate           77
# construction        51
# defamation          44
# insurance           27
# wrongful_death      23
# other               18
# products            17
# workers_comp        14
# Name: Case_Type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 7 columns):
# Opinion                 2747 non-null object
# SCT                     2747 non-null int64
# Year_Filed              2747 non-null int64
# File_Numbers            2747 non-null object
# Result                  2747 non-null object
# Case_Type               2747 non-null object
# Case_Type_Confidence    2747 non-null object
# dtypes: int64(2), object(5)
# memory usage: 150.4+ KB

# %% [markdown]
# ## 5.  Extract Feature: Trial-Court Judge

# %%
def trial_judge(opinion):
    """
    This function extracts the underlying trial judge
    from the opinion, typically falling between the 
    words, 'by judge ____ in'.  This try/except format
    recognizes the hierarchy from the most likely correct
    match to the lesser likely correct matches. The 
    form follows the Python EAFP principle.
    """
    try:
        try:
            try:
                try:
                    try:
                        try:
                            judge = re.search("by judge (\w+) (\w+) in", opinion)
                            f_name = judge.group(1)
                            l_name = judge.group(2)
                            pre_clean = [l_name, f_name]
                            name = [i for i in pre_clean if i != None]
                            return(name)
                        except:
                            judge = re.search("by (the honorable|judge) (\w+.?) ?(\w+.|-?)? ?(\w+),? ?(jr.|sr.|iii|ii|iv)?,? (?:in|and)", opinion)
                            f_name = judge.group(2)
                            m_name = judge.group(3)
                            l_name = judge.group(4)
                            suffx =  judge.group(5) 
                            pre_clean = [l_name, f_name, m_name, suffx]
                            name = [i for i in pre_clean if i != None]
                            return(name)
                    except:
                        judge = re.search("by (\w+.?), .?\.? ?j., in", opinion)
                        l_name = judge.group(1)
                        pre_clean = [l_name]
                        name = [i for i in pre_clean if i != None]
                        return(name)
                except:
                    judge = re.search("(the honorable|judge) (\w+.?) (\w+.|-?)? ?(\w+),? ?(jr.|sr.|iii|ii|iv)?,? (?:presiding|in|on)", opinion)
                    f_name = judge.group(2)
                    m_name = judge.group(3)
                    l_name = judge.group(4)
                    suffx =  judge.group(5) 
                    pre_clean = [l_name, f_name, m_name, suffx]
                    name = [i for i in pre_clean if i != None]
                    return(name)
            except:
                judge = re.search("by (\w+.?) (\w+.|-?)? ?(\w+),? ?(jr.|sr.|iii|ii|iv)?,? in", opinion[:1000])
                f_name = judge.group(1)
                m_name = judge.group(2)
                l_name = judge.group(3)
                suffx =  judge.group(4) 
                pre_clean = [l_name, f_name, m_name, suffx]
                name = [i for i in pre_clean if i != None]
                return(name)
        except:
            judge = re.search("by judge (\w+.?) (\w+.|-?)? ?(\w+),? ?(jr.|sr.|iii|ii|iv)?", opinion[:1000])
            f_name = judge.group(1)
            m_name = judge.group(2)
            l_name = judge.group(3)
            suffx =  judge.group(4) 
            pre_clean = [l_name, f_name, m_name, suffx]
            name = [i for i in pre_clean if i != None]
            return(name)     
    except:
        name = 'error'
        return(name)

# %%
# Apply function to the DataFrame
judges_list = []
for i in range(len(df.Opinion)):
    y = trial_judge(df.Opinion[i])
    judges_list.append(y)
    
df["Trial_Judge"] = pd.Series(judges_list).values

# %%
df.sample(10)
# Out:
#                                                 Opinion  SCT  Year_Filed File_Numbers    Result  \
# 2547  robert murdock, jr., beverly murdock, david w....    0        2009       08-809  affirmed
# 239   jimmy leff greene, joe bill greene, ronnie gle...    0        2003       02-882  affirmed
# 2007  robert willis, plaintiff v. town of beaufort, ...    0        2001       00-371  reversed
# 2524  hazel s. hawkins, as personal representative o...    0        2010        09-23  reversed
# 2052  sylvia youse, plaintiff-appellant, v. duke ene...    0        2005       04-797  affirmed
# 1968   in the court of appeals of north carolina no....    0        2018       17-756  affirmed
# 268    an unpublished opinion of the north carolina ...    0        2020        20-67  affirmed
# 2074   in the court of appeals of north carolina no....    0        2015      14-1393  affirmed
# 1454  karen b. orr and michael trexler, plaintiffs-a...    0        2011       10-480  affirmed
# 845    josie mcilwan blackwell, plaintiff, v. timoth...    0        2010       09-298  affirmed
#
#             Case_Type Case_Type_Confidence                  Trial_Judge
# 2547         property               100.0%        [titus, kenneth , c.]
# 239       fraud_udtpa               81.25%  [walker, russell , g., jr.]
# 2007     governmental               88.24%     [ragan, james , e., iii]
# 2524          med_mal               71.43%        [winner, dennis , j.]
# 2052       employment               95.65%           [cromer, anderson]
# 1968  landlord_tenant               48.78%            [gale, james, l.]
# 268          property               50.91%    [crosswhite, joseph , n.]
# 2074          estates               72.73%             [baddour, allen]
# 1454      fraud_udtpa                75.0%        [bridges, laura , j.]
# 845         car_crash               72.92%           [ford, larry , g.]

# %%
x = df.loc[df["Trial_Judge"] == 'error']
# After testing the results of x (the list of erros from the trial_judge function), 
# the unresolved errors were dropped; they were generally non-judicial decisions 
# (such as from administrative agencies) or decisions involving multiple orders
# from multiple judges.
drop_list_others = list(x.index)
df.drop(drop_list_others, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# Test function to review and diagnose issues
try:
    test_cell = int(input("Index to Test:"))
    print(trial_judge(df.Opinion[test_cell]),
          '\n\n', df.Opinion[test_cell])
except:
    print("Please enter an index to review:")
# Out:
# Index to Test:
# Please enter an index to review:

# %% [markdown]
# **Notes in resolving trial_judge errors**<br>
# 162 - multiple
# 204 - multiple
# 246 - nonjudicial
# 269 - nonjudicial
# 285 - 1stimpression
# 382 - multiple
# 452 - multiple
# 471 - nonjudicial
# 496 - nonjudicial
# 576 - nonjudicial
# 606 - multiple
# 664 - multiple
# 715 - nonjudicial
# 722 - SCT
# 779 - by administrative law judge beecher r. gray.
# 822 - multiple
# 851 - nonjudicial
# 853 - multiple
# 892 - nonjudicial
# 899 - nonjudicial
# 944 - multiple
# 1052 - nonjudicial
# 1081 - nonjudicial
# 1102 - nonjudicial
# 1104 - by superior court judge for complex business cases james l. gale in
# 1138 - multiple
# 1176 - SCT
# 1288 - multiple
# 1318 - nonjudicial
# 1373 - multiple
# 1396 - nonjudicial
# 1411 - multiple
# 1463 - multiple
# 1840 - nonjudicial
# 1886 - nonjudicial
# 1978 - nonjudicial
# 2066 - multiple
# 2083 - nonjudicial
# 2155 - SCT?
# 2206 - nonjudicial
# 2214 - nonjudicial
# 2225 - multiple
# 2251 - nonconforming
# 2261 - nonjudicial
# 2517 - nonjudicial
# 2533 - nonjudicial
# 2585 - nonjudicial
# 2625 - nonjudicial
# 2657 - nonjudicial
# 2678 - nonconforming

# %%
singles = []
counter = 0

for i in range(len(judges_)):
    if (len(judges_[i][0]) < 2):
        counter =+ 1
        singles.append(judges_[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a23784a338f4> in <module>
#       2 counter = 0
#       3
# ----> 4 for i in range(len(judges_)):
#       5     if (len(judges_[i][0]) < 2):
#       6         counter =+ 1
#
# NameError: name 'judges_' is not defined

# %%
# Need to remove these 
singles
# Out:
# []

# %%
judge_drop_list = [60,1878,209,507,618,340,574,567,606,796,1888,2304,2360,2493,815,2519,
                   1234,2474,1401,1405,1427,1599]   # y,k,z,e,r,g,n,t,s,m,l

# %%
# Test to remove error rows from judge name extraction
#df.Trial_Judge.loc[df.Trial_Judge.str.startswith('[\'m\'', na=False)]

# %%
df.drop(judge_drop_list, axis=0, inplace=True)

# %% [markdown]
# #### Make Judges' Names Only Two Words

# %%
judges = list(df['Trial_Judge'])

# %%
judges
# Out:
# [['williams', 'karen ', 'eady-'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['poovey', 'nathaniel ', 'j.'],
#  ['gore', 'william ', 'c.'],
#  ['stephens', 'donald ', 'w.'],
#  ['hinton', 'alma ', 'l.'],
#  ['williamson', 'f.', 'lane '],
#  ['walczyk', 'christine ', 'm.'],
#  ['winner', 'dennis ', 'j.'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['jenkins', 'knox ', 'v.'],
#  ['lewis', 'ola ', 'm.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['tennille', 'ben ', 'f.'],
#  ['williamson', 'f.', 'lane '],
#  ['downs', 'james ', 'u.'],
#  ['gessner', 'paul ', 'g.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['desvousges', 'shelley ', 'h.'],
#  ['helms', 'michael ', 'e.'],
#  ['johnston', 'robert ', 'p.'],
#  ['gottlieb', 'richard ', 's.'],
#  ['blount', 'marvin ', 'k.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['bray', 'susan ', 'e.'],
#  ['hinnant', 'patrice ', 'a.'],
#  ['seaton', 'sarah ', 'c.'],
#  ['fullwood', 'ernest ', 'b.'],
#  ['thornburg', 'alan ', 'z.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['titus', 'kenneth ', 'c.'],
#  ['albright', 'stuart'],
#  ['gessner', 'paul ', 'g.'],
#  ['murphy', 'calvin ', 'e.'],
#  ['bell', 'w.', 'robert '],
#  ['stanback', 'leon'],
#  ['doughton'],
#  ['cashwell', 'narley ', 'l.'],
#  ['collier', 'christopher'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['martin', 'jerry ', 'cash '],
#  ['bell', 'w.', 'robert '],
#  ['carter', 'clarence ', 'w.'],
#  ['orders', 'walter ', 'godwin,'],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['kincaid', 'timothy ', 's.'],
#  ['klass', 'mark ', 'e.'],
#  ['saunders', 'chase ', 'b.'],
#  ['spivey', 'ronald ', 'e.'],
#  ['tucker', 'kimbrell ', 'kelly '],
#  ['fox', 'carl ', 'r.'],
#  ['boner', 'richard ', 'd.'],
#  ['ross', 'thomas ', 'w.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['deramus', 'judson ', 'd.'],
#  ['ragan', 'james ', 'e.', 'iii'],
#  ['levinson', 'eric ', 'l.'],
#  ['stanback', 'a.', 'leon '],
#  ['letts', 'bradley ', 'b.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['collins', 'g.', 'bryan '],
#  ['barnette', 'henry ', 'v.', 'jr.'],
#  ['fullwood', 'ernest ', 'b.'],
#  ['crow', 'kenneth ', 'f.'],
#  ['caudill', 'j.', 'gentry '],
#  ['trawick', 'gary'],
#  ['rand', 'ripley ', 'e.'],
#  ['rand', 'ripley ', 'e.'],
#  ['burke', 'l.', 'todd '],
#  ['collier', 'christopher ', 'm.'],
#  ['joseph', 'shannon ', 'r.'],
#  ['cranford', 'dwight ', 'l.'],
#  ['brown', 'deborah ', 'p.'],
#  ['that', 'to', 'another;'],
#  ['blick', 'joseph'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['stanback', 'a.', 'leon ', 'jr.'],
#  ['diaz', 'albert'],
#  ['weeks', 'gregory ', 'a.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['foster', 'thomas ', 'g.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['trawick', 'gary ', 'e.'],
#  ['long', 'v.', 'bradford '],
#  ['collins', 'g.', 'bryan ', 'jr.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['winner', 'dennis ', 'j.'],
#  ['klass', 'mark ', 'e.'],
#  ['fox', 'carl ', 'r.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['royster', 'theodore ', 's.', 'jr.'],
#  ['alford', 'benjamin'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['long', 'v.', 'bradford '],
#  ['parker', 'regina ', 'r.'],
#  ['taylor', 'kimberly ', 's.'],
#  ['ellis', 'b.', 'craig '],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['johnston', 'robert ', 'p.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['jenkins', 'knox ', 'v.'],
#  ['collins', 'g.', 'bryan ', 'jr.'],
#  ['davis', 'j.', 'thomas '],
#  ['mcgee', 'martin ', 'b.'],
#  ['winner', 'dennis ', 'j.'],
#  ['stephens', 'donald ', 'w.'],
#  ['hill', 'evelyn ', 'w.'],
#  ['godwin', 'walter ', 'h.', 'jr.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['joseph', 'shannon ', 'r.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['hunt', 'jeff'],
#  ['tucker', 'kimbrell ', 'kelly '],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['cromer', 'andy'],
#  ['davis', 'j.', 'thomas '],
#  ['john', 'joseph ', 'r.'],
#  ['zimmerman', 'h.', 'w.', 'jr.'],
#  ['bowers', 'john ', 'w.'],
#  ['hooks', 'd.', 'jack ', 'jr.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['tennille', 'ben ', 'f.'],
#  ['morgan', 'michael ', 'r.'],
#  ['spivey', 'ronald ', 'e.'],
#  ['gottlieb', 'richard ', 's.'],
#  ['gore', 'william ', 'c.', 'jr.'],
#  ['baddour', 'r.', 'allen ', 'jr.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['brown', 'frank ', 'r.'],
#  ['stiehl', 'robert ', 'j.', 'iii'],
#  ['albright'],
#  ['martin', 'jerry ', 'cash '],
#  ['gore'],
#  ['croom', 'craig'],
#  ['fox', 'carl ', 'r.'],
#  ['joseph', 'shannon'],
#  ['cashwell', 'narley ', 'l.'],
#  ['ford', 'larry ', 'g.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['titus', 'kenneth'],
#  ['lock', 'thomas ', 'h.'],
#  ['stephens', 'donald ', 'w.'],
#  ['cooper', 'pell ', 'c.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['boner', 'richard ', 'd.'],
#  ['miller', 'gordon'],
#  ['eagles', 'catherine ', 'c.'],
#  ['bowen', 'wiley ', 'f.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['doughton', 'richard ', 'l.'],
#  ['albright', 'stuart'],
#  ['murphy', 'calvin ', 'e.'],
#  ['morgan', 'michael', 'r.'],
#  ['albright', 'r.', 'stuart '],
#  ['sitton', 'claude ', 's.'],
#  ['parker', 'j.', 'richard '],
#  ['faison', 'james ', 'h.', 'iii'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['doughton', 'richard ', 'l.'],
#  ['barnette', 'henry ', 'v.'],
#  ['patti', 'timothy ', 'l.'],
#  ['powell', 'mark ', 'e.'],
#  ['locklear', 'gary ', 'l.'],
#  ['horne', 'r.', 'gregory '],
#  ['stephens', 'ronald ', 'l.'],
#  ['winner', 'dennis ', 'j.'],
#  ['mclean', 'mitchell ', 'l.'],
#  ['hockenbury', 'jay ', 'd.'],
#  ['rand', 'ripley ', 'e.'],
#  ['bridges', 'forrest ', 'd.'],
#  ['baddour', 'r.', 'allen '],
#  ['winner', 'dennis ', 'j.'],
#  ['allen', 'j.', 'b.', 'jr.'],
#  ['fitch', 'milton ', 'f.', 'jr.'],
#  ['spencer', 'james ', 'c.'],
#  ['ridgeway', 'paul ', 'c.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['gorham', 'phyllis ', 'm.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['hudson', 'orlando ', 'f.'],
#  ['allen', 'j.', 'b.', 'jr.'],
#  ['doughton', 'richard ', 'l.'],
#  ['patti', 'timothy ', 'l.'],
#  ['ammons', 'james ', 'floyd ', 'jr.'],
#  ['thompson', 'jack ', 'a.'],
#  ['ammons', 'james ', 'f.', 'jr.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['labarre', 'david ', 'q.'],
#  ['davis', 'amber'],
#  ['parker', 'j.', 'richard '],
#  ['allen', 'j.', 'b.', 'jr.'],
#  ['bridges', 'kevin ', 'm.'],
#  ['dameron', 'e.', 'penn ', 'jr.'],
#  ['coward', 'william ', 'h.'],
#  ['cornelius', 'preston'],
#  ['vosburg', 'james'],
#  ['burke', 'l.', 'todd '],
#  ['labarre', 'david ', 'q.'],
#  ['parker', 'regina ', 'r.'],
#  ['gregory', 'edgar'],
#  ['hobgood', 'robert ', 'h.'],
#  ['cella', 'eugene ', 'j.'],
#  ['leake', 'larry ', 'b.'],
#  ['carter', 'clarence', 'w.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['gessner', 'paul ', 'g.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['knight', 'peter ', 'b.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['thompson', 'carolyn ', 'j.'],
#  ['hamby', 'william ', 'g.', 'jr.'],
#  ['strickland', 'james ', 'r.'],
#  ['griffin', 'william'],
#  ['burke', 'l.', 'todd '],
#  ['hudson', 'orlando ', 'f.'],
#  ['pool', 'c.', 'randy '],
#  ['poovey', 'nathaniel'],
#  ['crosswhite', 'joseph ', 'n.'],
#  ['nobles', 'john ', 'e.', 'jr.'],
#  ['albright', 'r.', 'stuart '],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['kincaid', 'timothy ', 's.'],
#  ['powell', 'mark ', 'e.'],
#  ['henry', 'charles ', 'h.'],
#  ['morton', 'j.', 'bruce '],
#  ['spencer', 'james ', 'c.', 'jr.'],
#  ['walker', 'russell ', 'g.', 'jr.'],
#  ['baker', 'james ', 'l.', 'jr.'],
#  ['cashwell', 'narley ', 'l.'],
#  ['bullock', 'stafford ', 'g.'],
#  ['smith', 'osmond'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['payne', 'ronald ', 'k.'],
#  ['fox', 'carl ', 'r.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['frye', 'henry ', 'e.', 'jr.'],
#  ['hyatt', 'marlene'],
#  ['lewis', 'ola ', 'm.'],
#  ['klass', 'mark ', 'e.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['gessner', 'paul ', 'g.'],
#  ['tennille', 'ben ', 'f.'],
#  ['hudson', 'orlando'],
#  ['gregory', 'edgar ', 'b.'],
#  ['foster', 'thomas ', 'g.'],
#  ['gavenus', 'gary ', 'm.'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['walker', 'russell ', 'g.', 'jr.'],
#  ['bogle', 'ronald ', 'e.'],
#  ['burke', 'l.', 'todd '],
#  ['cromer', 'andy'],
#  ['jones', 'arnold ', 'o.'],
#  ['ellis', 'b.', 'craig '],
#  ['crosswhite', 'joseph ', 'n.'],
#  ['judgment', 'granting', 'summary '],
#  ['gessner', 'paul ', 'g.'],
#  ['alford', 'benjamin ', 'g.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['fox', 'carl ', 'r.'],
#  ['nobles', 'john ', 'e.', 'jr.'],
#  ['webb', 'james ', 'm.'],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['crosswhite', 'joseph ', 'n.'],
#  ['stephens', 'ronald ', 'l.'],
#  ['baddour', 'allen'],
#  ['inman', 'lucy ', 'n.'],
#  ['hooks', 'd.', 'jack ', 'jr.'],
#  ['turner', 'r.', 'les '],
#  ['tennille', 'ben ', 'f.'],
#  ['albright', 'w.', 'douglas '],
#  ['john', 'joseph ', 'r.', 'sr.'],
#  ['balog', 'steve'],
#  ['albright', 'w.', 'douglas '],
#  ['joseph', 'shannon ', 'r.'],
#  ['gavenus', 'gary ', 'm.'],
#  ['stephens', 'donald ', 'w.'],
#  ['stephens', 'donald ', 'w.'],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['alford', 'benjamin ', 'g.'],
#  ['johnson', 'e.', 'lynn '],
#  ['sumner', 'quentin ', 't.'],
#  ['hill', 'evelyn ', 'w.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['gale', 'james ', 'l.'],
#  ['overby', 'donald', 'w.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['lawton', 'william ', 'c.'],
#  ['spivey', 'ronald ', 'e.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['mccormick', 'edward ', 'h.'],
#  ['sitton', 'claude ', 's.'],
#  ['phillips', 'herbert', 'o.', 'iii'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['bell', 'w.', 'robert '],
#  ['tennille', 'ben ', 'f.'],
#  ['morgan', 'melzer ', 'a.', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['wilson', 'edwin ', 'g.', 'jr.'],
#  ['barrett', 'sharon ', 'tracey '],
#  ['webb', 'james ', 'm.'],
#  ['watson', 'ebern ', 't.', 'iii'],
#  ['lewis', 'ola ', 'm.'],
#  ['butterfield', 'g.', 'k.'],
#  ['mcswain', 'lawrence ', 'c.'],
#  ['abernethy', 'richard ', 'b.'],
#  ['thompson', 'jack'],
#  ['hughes', 'f.', 'warren '],
#  ['tilghman', 'carl'],
#  ['johnson', 'marcus ', 'l.'],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['johnson', 'e.', 'lynn '],
#  ['bridges', 'forrest ', 'd.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['johnson', 'e.', 'lynn '],
#  ['staton', 'kimberly ', 'best-'],
#  ['cornelius', 'preston'],
#  ['gray', 'marvin ', 'k.'],
#  ['stephens', 'donald ', 'w.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['kincaid', 'timothy ', 's.'],
#  ['gray', 'beecher ', 'r.'],
#  ['weeks', 'gregory ', 'a.'],
#  ['cashwell', 'narley ', 'l.'],
#  ['bell', 'lisa ', 'c.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['morgan', 'michael ', 'r.'],
#  ['mchugh', 'peter ', 'm.'],
#  ['jones', 'arnold ', 'o.', 'ii'],
#  ['rand', 'ripley ', 'e.'],
#  ['helms', 'michael ', 'e.'],
#  ['boner', 'richard ', 'd.'],
#  ['powell', 'mark ', 'e.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['weeks', 'gregory'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['tennille', 'ben ', 'f.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['grant', 'cy ', 'a.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['lee', 'w.', 'david '],
#  ['balog', 'steve ', 'a.'],
#  ['bray', 'susan ', 'e.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['beale', 'michael ', 'e.'],
#  ['thornburg', 'alan ', 'z.'],
#  ['gorham', 'phyllis ', 'm.'],
#  ['bullock', 'stafford ', 'g.'],
#  ['lewis', 'ola ', 'm.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['webb', 'james ', 'm.'],
#  ['balog', 'steve ', 'a.'],
#  ['titus', 'kenneth ', 'c.'],
#  ['lewis', 'ola ', 'm.'],
#  ['kwasikpui', 'alfred ', 'w.'],
#  ['tally', 'mary ', 'ann '],
#  ['jenkins', 'jack ', 'w.'],
#  ['titus', 'kenneth ', 'c.'],
#  ['rousseau', 'julius ', 'a.', 'jr.'],
#  ['downs', 'james ', 'u.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['lock', 'thomas ', 'h.'],
#  ['webb', 'james ', 'm.'],
#  ['herring', 'd.', 'b.', 'jr.'],
#  ['payne', 'ronald ', 'k.'],
#  ['jones', 'abraham ', 'penn '],
#  ['alford', 'benjamin ', 'g.'],
#  ['z', 'albert ', 'dia'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['spencer', 'james ', 'c.', 'jr.'],
#  ['alford', 'benjamin ', 'g.'],
#  ['letts', 'bradley ', 'b.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['diaz', 'albert'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['gray', 'beecher ', 'r.'],
#  ['beal', 'beverly ', 't.'],
#  ['ervin', 'robert ', 'c.'],
#  ['zimmerman', 'h.', 'w.', 'jr.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['jones', 'abraham ', 'penn '],
#  ['freeman', 'william ', 'h.'],
#  ['ammons', 'james ', 'f.'],
#  ['johnson', 'e.', 'lynn '],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['walker', 'russell ', 'g.', 'jr.'],
#  ['helms', 'michael ', 'e.'],
#  ['rader', 'robert ', 'b.'],
#  ['blount', 'marvin ', 'k.'],
#  ['burke', 'l.', 'todd '],
#  ['cromer', 'anderson'],
#  ['ervin', 'robert ', 'c.'],
#  ['warren', 'steve'],
#  ['beal', 'beverly ', 't.'],
#  ['wilson', 'edwin ', 'g.'],
#  ['spencer', 'cheryl'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['rousseau', 'julius ', 'a.', 'jr.'],
#  ['cole', 'j.', 'carlton '],
#  ['brantley', 'david ', 'b.'],
#  ['winner', 'dennis ', 'j.'],
#  ['payne', 'ronald ', 'k.'],
#  ['parsons', 'w.', 'douglas '],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['fox', 'carl ', 'r.'],
#  ['winner', 'dennis ', 'j.'],
#  ['floyd', 'robert ', 'f.', 'jr.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['ervin', 'robert ', 'c.'],
#  ['brown', 'richard ', 't.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['winner', 'dennis ', 'j.'],
#  ['ginn', 'c.', 'phillip '],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['smith', 'timothy ', 'm.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['brown', 'frank ', 'r.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['hinnant', 'patrice'],
#  ['gorham', 'phyllis ', 'm.'],
#  ['barnette', 'henry ', 'v.', 'jr.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['thompson', 'jack ', 'a.'],
#  ['bell', 'lisa ', 'c.'],
#  ['joseph', 'shannon'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['craig', 'john ', 'o.'],
#  ['godwin', 'walter ', 'h.'],
#  ['godwin', 'walter ', 'h.', 'jr.'],
#  ['collier', 'christopher ', 'm.'],
#  ['tillett', 'jerry ', 'r.'],
#  ['jones', 'paul ', 'l.'],
#  ['everett', 'clifton ', 'w.', 'jr.'],
#  ['tennille', 'ben ', 'f.'],
#  ['webb', 'james ', 'm.'],
#  ['farmer', 'robert ', 'l.'],
#  ['morgan', 'michael ', 'r.'],
#  ['henry', 'charles ', 'h.'],
#  ['haigwood', 'thomas ', 'd.'],
#  ['payne', 'ronald ', 'k.'],
#  ['crow', 'kenneth ', 'f.'],
#  ['deramus', 'judson ', 'd.', 'jr.'],
#  ['roberson', 'james ', 'k.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['letts', 'bradley ', 'b.'],
#  ['spencer', 'james ', 'c.', 'jr.'],
#  ['cashwell', 'narley ', 'l.'],
#  ['stephens', 'donald ', 'w.'],
#  ['klass', 'mark ', 'e.'],
#  ['lamm', 'charles ', 'c.', 'jr.'],
#  ['gessner', 'paul ', 'g.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['fox', 'carl ', 'r.'],
#  ['jenkins', 'knox ', 'v.', 'jr.'],
#  ['helms', 'william ', 'h.'],
#  ['pope', 'marvin ', 'p.', 'jr.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['parker', 'j.', 'richard '],
#  ['hockenbury', 'jay ', 'd.'],
#  ['hill', 'evelyn ', 'w.'],
#  ['henry', 'charles ', 'h.'],
#  ['sumner', 'quentin ', 't.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['henry', 'charles'],
#  ['cobb'],
#  ['foster', 'jefferey'],
#  ['sumner', 'robert ', 't.'],
#  ['grimes', 'samuel ', 'g.'],
#  ['long', 'v.', 'bradford '],
#  ['davis', 'danny', 'e.'],
#  ['downs', 'james ', 'u.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['foy', 'louis ', 'f.', 'jr.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['allsbrook', 'richard ', 'b.'],
#  ['locklear', 'gary ', 'l.'],
#  ['wallace', 'tanya ', 't.'],
#  ['klass', 'mark ', 'e.'],
#  ['payne', 'ronald ', 'k.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['blount', 'marvin ', 'k.'],
#  ['dameron', 'e.', 'penn ', 'jr.'],
#  ['massey', 'a.', 'moses '],
#  ['nobles', 'john ', 'e.', 'jr.'],
#  ['banks', 'j.', 'henry '],
#  ['floyd', 'r.', 'frank '],
#  ['tennille', 'ben ', 'f.'],
#  ['gessner', 'paul ', 'g.'],
#  ['helms', 'michael ', 'e.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['morgan', 'james ', 'w.', 'jr.'],
#  ['williamson', 'f.', 'lane '],
#  ['ferrell', 'forrest ', 'a.'],
#  ['knight', 'peter'],
#  ['thompson', 'jack', 'a.'],
#  ['allen', 'j.', 'b.', 'jr.'],
#  ['kincaid', 'timothy ', 's.'],
#  ['gray', 'marvin ', 'k.'],
#  ['caudill', 'j.', 'gentry '],
#  ['baddour', 'allen'],
#  ['patti', 'timothy ', 'l.'],
#  ['collins', 'george ', 'b.', 'jr.'],
#  ['bell', 'james ', 'g.'],
#  ['ammons', 'james ', 'f.', 'jr.'],
#  ['wood', 'william ', 'z.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['letts', 'bradley ', 'b.'],
#  ['downs', 'james ', 'u.'],
#  ['baker', 'james ', 'l.', 'jr.'],
#  ['helms', 'michael ', 'e.'],
#  ['collins', 'g.', 'bryan ', 'jr.'],
#  ['gardner', 'john ', 'm.'],
#  ['joseph', 'shannon ', 'r.'],
#  ['gale', 'james ', 'l.'],
#  ['sermons', 'wayland ', 'j.', 'jr.'],
#  ['taylor', 'kim ', 's.'],
#  ['ridgeway', 'paul ', 'c.'],
#  ['jenkins', 'knox ', 'v.', 'jr.'],
#  ['gregory', 'edgar ', 'b.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['bridges', 'forrest ', 'd.'],
#  ['lanning', 'james ', 'e.'],
#  ['bell', 'james ', 'gregory '],
#  ['diaz', 'albert'],
#  ['faison', 'james ', 'h.', 'iii'],
#  ['manning', 'howard ', 'e.'],
#  ['powell', 'mark ', 'e.'],
#  ['bridges', 'forrest ', 'donald '],
#  ['barber', 'wade'],
#  ['johnson', 'marcus ', 'l.'],
#  ['beal'],
#  ['blount', 'marvin ', 'k.', 'iii'],
#  ['beale', 'michael ', 'e.'],
#  ['klass', 'mark ', 'e.'],
#  ['collier', 'christopher ', 'm.'],
#  ['long', 'vance ', 'bradford '],
#  ['taylor', 'kimberly ', 's.'],
#  ['harper', 'jane ', 'v.'],
#  ['winner', 'dennis ', 'j.'],
#  ['tennille', 'ben ', 'f.'],
#  ['horne', 'r.', 'greg '],
#  ['tennille', 'ben ', 'f.'],
#  ['beale', 'michael ', 'e.'],
#  ['lewis', 'hugh ', 'b.'],
#  ['graham'],
#  ['walker', 'richard ', 'k.'],
#  ['mchugh', 'peter ', 'm.'],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['bowen', 'wiley ', 'f.'],
#  ['spencer', 'james ', 'c.', 'jr.'],
#  ['sumner', 'quentin ', 't.'],
#  ['harrell', 'r.', 'kent '],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['royster', 'theodore ', 's.', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['norelli', 'nancy ', 'b.'],
#  ['freeman', 'william ', 'h.'],
#  ['hockenbury', 'jay ', 'd.'],
#  ['rand', 'ripley ', 'e.'],
#  ['parker', 'j.', 'richard '],
#  ['rader', 'robert ', 'b.'],
#  ['evans', 'yvonne ', 'mims '],
#  ['spainhour', 'w.', 'erwin '],
#  ['gottlieb', 'richard ', 's.'],
#  ['gore', 'william ', 'c.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['jenkins', 'jack ', 'w.'],
#  ['doughton', 'richard ', 'l.'],
#  ['shirley', 'a.', 'graham '],
#  ['spainhour', 'w.', 'erwin '],
#  ['williamson', 'f.', 'lane '],
#  ['ervin', 'robert ', 'c.'],
#  ['lewis', 'robert ', 'd.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['hockenbury', 'jay ', 'd.'],
#  ['greeson', 'howard ', 'r.', 'jr.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['lee', 'w.', 'david '],
#  ['helms', 'michael ', 'e.'],
#  ['gregory', 'edgar ', 'b.'],
#  ['winner', 'dennis ', 'j.'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['watson', 'ebern ', 't.', 'iii'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['albright', 'w.', 'douglas '],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['nobles', 'john ', 'e.'],
#  ['brown', 'shirley ', 'h.'],
#  ['sumner', 'quentin ', 't.'],
#  ['gorham', 'phyllis ', 'm.'],
#  ['barnette', 'henry ', 'v.', 'jr.'],
#  ['cromer', 'anderson ', 'd.'],
#  ['titus', 'kenneth ', 'c.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['tennille', 'ben ', 'f.'],
#  ['stephens', 'donald ', 'w.'],
#  ['klass', 'mark ', 'e.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['doughton', 'richard ', 'l.'],
#  ['bridges', 'forrest ', 'd.'],
#  ['labarre', 'david ', 'q.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['tillett', 'jerry ', 'r.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['coward', 'william ', 'h.'],
#  ['rand', 'ripley ', 'e.'],
#  ['barnette', 'henry ', 'v.', 'jr.'],
#  ['sitton', 'claude ', 's.'],
#  ['lamm', 'charles ', 'c.', 'jr.'],
#  ['frye', 'henry ', 'e.', 'jr.'],
#  ['godwin', 'walter ', 'h.', 'jr.'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['reviewable', 'and', 'is '],
#  ['stephens', 'donald ', 'w.'],
#  ['fox', 'carl ', 'r.'],
#  ['stanback', 'a.', 'leon ', 'jr.'],
#  ['joseph', 'shannon'],
#  ['tilghman', 'carl ', 'l.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['albright', 'r.', 'stuart '],
#  ['walker', 'russell ', 'g.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['balog', 'steve ', 'a.'],
#  ['parsons', 'w.', 'douglas '],
#  ['allsbrook', 'richard ', 'b.'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['joseph', 'shannon ', 'r.'],
#  ['brown', 'frank ', 'r.'],
#  ['patti', 'timothy ', 'lee '],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['stanback', 'a.', 'leon ', 'jr.'],
#  ['balog', 'steve ', 'a.'],
#  ['diaz', 'albert'],
#  ['kincaid', 'timothy ', 's.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['gilchrist', 'c.', 'winston '],
#  ['morgan', 'eric ', 'c.'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['corbett', 'albert ', 'a.', 'jr.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['johnston', 'robert ', 'p.'],
#  ['kincaid', 'timothy'],
#  ['klass', 'mark ', 'e.'],
#  ['caldwell', 'jesse ', 'b.'],
#  ['miller', 'regan ', 'a.'],
#  ['jones', 'paul ', 'l.'],
#  ['tally', 'mary ', 'ann '],
#  ['evans', 'robert ', 'a.'],
#  ['payne', 'ronald ', 'k.'],
#  ['gray', 'jane ', 'p.'],
#  ['hooks', 'd.', 'jack ', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['oneal', 'elaine ', 'm.'],
#  ['hedrick', 'edward ', 'l.', 'iv'],
#  ['taylor', 'kimberly ', 's.'],
#  ['gray', 'jane ', 'p.'],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['helms', 'michael ', 'e.'],
#  ['cashwell', 'narley'],
#  ['albright', 'w.', 'douglas '],
#  ['doughton', 'richard ', 'l.'],
#  ['adkins', 'karl'],
#  ['ford', 'larry ', 'g.'],
#  ['steelman', 'sanford ', 'l.', 'jr.'],
#  ['thalheimer', 'ben ', 's.'],
#  ['burke', 'l.', 'todd '],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['bell', 'w.', 'robert '],
#  ['wood', 'william ', 'z.', 'jr.'],
#  ['evans', 'yvonne ', 'mims '],
#  ['burke', 'l.', 'todd '],
#  ['rader', 'robert ', 'b.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['carolina', 'the', 'north '],
#  ['albright', 'w.', 'douglas '],
#  ['hodges', 'robert ', 'e.'],
#  ['faison', 'james ', 'h.', 'iii'],
#  ['cromer', 'anderson ', 'd.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['keever', 'a.', 'elizabeth '],
#  ['beal', 'beverly ', 't.'],
#  ['winner', 'dennis ', 'j.'],
#  ['fitch', 'milton ', 'f.', 'jr.'],
#  ['trawick', 'gary ', 'e.'],
#  ['desvousges', 'shelley ', 'h.'],
#  ['ridgeway', 'paul ', 'c.'],
#  ['grant', 'cy ', 'a.', 'sr.'],
#  ['boner', 'richard ', 'd.'],
#  ['trawick', 'gary ', 'e.'],
#  ['alford', 'benjamin ', 'g.'],
#  ['nobles', 'john ', 'e.'],
#  ['burke', 'l.', 'todd '],
#  ['ammons', 'james ', 'f.', 'jr.'],
#  ['johnston', 'robert ', 'p.'],
#  ['john', 'joseph ', 'r.', 'sr.'],
#  ['evans', 'yvonne ', 'mims '],
#  ['spainhour', 'w.', 'erwin '],
#  ['stephens', 'donald ', 'w.'],
#  ['stanback', 'a.', 'leon ', 'jr.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['brewer', 'coy ', 'e.', 'jr.'],
#  ['klass', 'mark ', 'e.'],
#  ['parker', 'j.', 'richard '],
#  ['fox', 'carl ', 'r.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['morgan', 'michael ', 'r.'],
#  ['horne', 'r.', 'gregory '],
#  ['johnston', 'robert ', 'p.'],
#  ['labarre', 'david ', 'q.'],
#  ['wilhelm', 'christy ', 'e.'],
#  ['kincaid', 'timothy'],
#  ['hinton', 'alma ', 'l.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['ford', 'larry'],
#  ['braswell', 'b.', 'jerry '],
#  ['lewis', 'robert ', 'd.'],
#  ['boner', 'richard ', 'd.'],
#  ['nobles', 'john ', 'e.', 'jr.'],
#  ['titus', 'kenneth ', 'c.'],
#  ['adkins', 'karl'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['boner', 'richard'],
#  ['powell', 'mark ', 'e.'],
#  ['barnette', 'henry ', 'v.', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['battle', 'f.', 'gordon '],
#  ['klass', 'mark ', 'e.'],
#  ['hinton', 'alma ', 'l.'],
#  ['patti', 'timothy'],
#  ['lock', 'thomas ', 'h.'],
#  ['downs', 'james ', 'u.'],
#  ['hobgood', 'robert ', 'h.'],
#  ['lanning', 'james ', 'e.'],
#  ['cobb', 'w.', 'allen '],
#  ['kuehnert', 'daniel ', 'a.'],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['stephens', 'donald ', 'w.'],
#  ['ellis', 'craig'],
#  ['ennis', 'spencer ', 'byron '],
#  ['godwin', 'walter ', 'h.', 'jr.'],
#  ['stanback', 'a.', 'leon ', 'jr.'],
#  ['morey', 'marcia ', 'h.'],
#  ['trawick', 'gary ', 'e.'],
#  ['frye', 'henry ', 'e.', 'jr.'],
#  ['joseph', 'shannon ', 'r.'],
#  ['hill', 'evelyn ', 'werth '],
#  ['caviness', 'loto ', 'g.'],
#  ['gray', 'marvin ', 'k.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['corbett', 'albert ', 'a.', 'jr.'],
#  ['tennille', 'ben ', 'f.'],
#  ['winner', 'dennis ', 'j.'],
#  ['ridgeway', 'paul ', 'c.'],
#  ['spivey', 'ronald ', 'e.'],
#  ['houston', 'jeanie ', 'r.'],
#  ['hockenbury', 'jay ', 'd.'],
#  ['jones', 'abraham ', 'penn '],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['fox', 'carl ', 'r.'],
#  ['gray', 'marvin ', 'k.'],
#  ['baker', 'james ', 'l.', 'jr.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['john', 'joseph ', 'r.'],
#  ['cashwell', 'narley', 'l.'],
#  ['collier', 'christopher ', 'm.'],
#  ['cayer', 'david ', 's.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['hall', 'david ', 'l.'],
#  ['hill', 'james ', 't.'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['bridges', 'forrest ', 'd.'],
#  ['stanback', 'a.', 'leon '],
#  ['stephens', 'donald ', 'w.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['cashwell'],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['johnston', 'robert ', 'p.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['cashwell', 'narley ', 'l.'],
#  ['jenkins', 'jack ', 'w.'],
#  ['weeks', 'gregory ', 'a.'],
#  ['wood', 'william ', 'z.'],
#  ['gorham', 'phyllis ', 'm.'],
#  ['jenkins', 'jack ', 'w.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['gottlieb', 'richard ', 's.'],
#  ['bullock', 'stafford ', 'g.'],
#  ['hyatt', 'j.', 'marlene '],
#  ['poovey', 'nathaniel ', 'j.'],
#  ['patti', 'timothy ', 'l.'],
#  ['hardin', 'james ', 'e.'],
#  ['baker', 'james ', 'l.'],
#  ['jones', 'paul ', 'l.'],
#  ['horton', 'clarence ', 'e.', 'jr.'],
#  ['powell', 'mark ', 'e.'],
#  ['ford', 'larry ', 'g.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['allen', 'j.', 'b.', 'jr.'],
#  ['johnston', 'robert ', 'p.'],
#  ['harrell', 'r.', 'kent '],
#  ['sermons', 'wayland ', 'j.', 'jr.'],
#  ['faison', 'james ', 'h.', 'iii'],
#  ['kincaid', 'timothy ', 's.'],
#  ['grant', 'cy ', 'a.'],
#  ['downs', 'james ', 'u.'],
#  ['gessner', 'paul ', 'g.'],
#  ['hill', 'james ', 'calvin '],
#  ['poovey', 'nathaniel ', 'j.'],
#  ['morgan', 'michael ', 'r.'],
#  ['ervin', 'robert ', 'c.'],
#  ['stone', 'richard ', 'w.'],
#  ['hudson', 'orlando ', 'f.'],
#  ['freeman', 'william ', 'h.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['bell', 'j.', 'gregory '],
#  ['lewis', 'ola ', 'm.'],
#  ['evans', 'yvonne ', 'mims '],
#  ['wilson', 'edwin ', 'g.', 'jr.'],
#  ['johnson', 'marcus ', 'l.'],
#  ['ridgeway', 'paul ', 'c.'],
#  ['albright', 'w.', 'douglas '],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['jones', 'william ', 'g.'],
#  ['webb', 'james ', 'm.'],
#  ['beal', 'beverly ', 't.'],
#  ['cobb', 'w.', 'allen ', 'jr.'],
#  ['henry', 'charles ', 'h.'],
#  ['patti', 'timothy ', 'l.'],
#  ['bledsoe', 'louis ', 'a.', 'iii'],
#  ['albright', 'r.', 'stuart '],
#  ['griffin', 'william ', 'c.', 'jr.'],
#  ['sumner', 'quentin ', 't.'],
#  ['trosch', 'elizabeth ', 't.'],
#  ['ferrell', 'forrest ', 'a.'],
#  ['jarrell', 'h.', 'thomas ', 'jr.'],
#  ['hardin', 'james ', 'e.', 'jr.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['evans', 'robert ', 'a.'],
#  ['deramus', 'judson ', 'd.', 'jr.'],
#  ['caviness', 'loto ', 'g.'],
#  ['duke', 'w.', 'russell ', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['cashwell', 'narley ', 'l.'],
#  ['hooks', 'd.', 'jack ', 'jr.'],
#  ['parker', 'j.', 'richard '],
#  ['webb', 'james ', 'm.'],
#  ['deramus'],
#  ['lewis', 'hugh ', 'b.'],
#  ['doughton', 'richard ', 'l.'],
#  ['gessner', 'paul ', 'g.'],
#  ['brady', 'robert ', 'm.'],
#  ['inman', 'lucy ', 'n.'],
#  ['bowen', 'wiley ', 'f.'],
#  ['gessner', 'paul ', 'g.'],
#  ['bell', 'w.', 'robert '],
#  ['jones', 'paul ', 'l.'],
#  ['strickland', 'james ', 'r.'],
#  ['klass', 'mark ', 'e.'],
#  ['poovey', 'nathaniel'],
#  ['harrison', 'hal ', 'g.'],
#  ['fullwood', 'ernest ', 'b.'],
#  ['thornburg', 'alan ', 'z.'],
#  ['brannon', 'anthony ', 'm.'],
#  ['joseph', 'shannon ', 'r.'],
#  ['albright', 'stuart'],
#  ['wilson', 'edwin ', 'g.'],
#  ['jones', 'abraham ', 'penn '],
#  ['collier', 'christopher ', 'm.'],
#  ['iii', 'james ', 'faison,'],
#  ['jones', 'paul ', 'l.'],
#  ['caldwell', 'jesse'],
#  ['gregory', 'edgar ', 'b.'],
#  ['jenkins', 'knox ', 'v.', 'jr.'],
#  ['collins', 'g.', 'bryan '],
#  ['alford', 'benjamin ', 'g.'],
#  ['jolly', 'john ', 'r.', 'jr.'],
#  ['trosch', 'louis ', 'a.'],
#  ['corbett', 'a.', 'a.', 'jr.'],
#  ['taylor', 'kimberly ', 's.'],
#  ['baddour', 'r.', 'allen ', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['bridges', 'forrest ', 'd.'],
#  ['spainhour', 'w.', 'erwin '],
#  ['spencer', 'james ', 'c.', 'jr.'],
#  ['conrad', 'adam'],
#  ['caldwell', 'jesse ', 'b.', 'iii'],
#  ['helms', 'michael ', 'e.'],
#  ['lewis', 'hugh ', 'b.'],
#  ['massey', 'moses ', 'a.'],
#  ['smith', 'w.', 'osmond '],
#  ['knox', 'michael ', 'g.'],
#  ['davis', 'j.', 'thomas '],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['manning', 'howard ', 'e.', 'jr.'],
#  ['beale', 'michael ', 'e.'],
#  ['robinson', 'michael ', 'l.'],
#  ['morgan', 'michael ', 'r.'],
#  ['caudill', 'j.', 'gentry '],
#  ['blount', 'marvin ', 'k.', 'iii'],
#  ['strickland', 'david ', 'h.'],
#  ['hill', 'evelyn ', 'w.'],
#  ['ward', 'j.', 'randolph '],
#  ['wilson', 'edwin ', 'g.', 'jr.'],
#  ['gregory', 'keith'],
#  ['hudson', 'orlando ', 'f.', 'jr.'],
#  ['lanier', 'russell ', 'j.', 'jr.'],
#  ['lock', 'thomas ', 'h.'],
#  ['sumner', 'quentin ', 't.'],
#  ['hill', 'evelyn ', 'w.'],
#  ['johnston', 'robert ', 'p.'],
#  ['bridges', 'forrest ', 'd.'],
#  ['lassiter', 'melissa', 'owens '],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['cobb', 'w.', 'allen '],
#  ['payne', 'ronald ', 'k.'],
#  ['downs', 'james ', 'u.'],
#  ['smith', 'w.', 'osmond ', 'iii'],
#  ['hooks', 'd.', 'jack ', 'jr.'],
#  ['gilchrist', 'c.', 'winston '],
#  ['crow', 'kenneth ', 'f.'],
#  ['davis', 'lindsay ', 'r.', 'jr.'],
#  ['hobgood', 'robert ', 'h.'],
#  ['eagles', 'catherine ', 'c.'],
#  ['crow', 'kenneth ', 'f.'],
#  ['wallace', 'tanya'],
#  ['hyatt', 'j.', 'marlene '],
#  ['wood', 'william ', 'z.', 'jr.'],
#  ['lewis', 'ola ', 'm.'],
#  ['deramus', 'judson ', 'd.', 'jr.'],
#  ['hight', 'henry ', 'w.', 'jr.'],
#  ['ginn', 'charles ', 'p.'],
#  ['collier', 'christopher ', 'm.'],
#  ['collins', 'g.', 'bryan ', 'jr.'],
#  ['parker', 'richard'],
#  ['gavenus', 'gary'],
#  ['labarre', 'david ', 'q.'],
#  ['morgan', 'michael ', 'r.'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['faison', 'james ', 'h.', 'iii'],
#  ['eagles', 'catherine ', 'c.'],
#  ['thompson', 'jack ', 'a.'],
#  ['cromer', 'andy'],
#  ['beale', 'michael ', 'e.'],
#  ['payne', 'ronald ', 'k.'],
#  ['diaz', 'albert'],
#  ['haigwood', 'thomas ', 'd.'],
#  ['corbett', 'albert ', 'a.', 'jr.'],
#  ['davis', 'tommy'],
#  ['caviness'],
#  ['eagles', 'catherine ', 'c.'],
#  ['shirley', 'a.', 'graham '],
#  ['hobgood', 'robert ', 'h.'],
#  ['jones', 'abraham ', 'penn '],
#  ['hinnant', 'patrice ', 'a.'],
#  ['pope', 'marvin ', 'p.', 'jr.'],
#  ['thornburg', 'alan ', 'z.'],
#  ['ferrell', 'forrest ', 'a.'],
#  ['helms', 'michael ', 'e.'],
#  ['letts', 'bradley ', 'b.'],
#  ['winner', 'dennis'],
#  ['alford', 'benjamin ', 'g.'],
#  ['tillett', 'jerry ', 'r.'],
#  ['shirley', 'a.', 'graham '],
#  ['doughton', 'richard'],
#  ['horton', 'clarence ', 'e.', 'jr.'],
#  ['diaz', 'albert'],
#  ['guice', 'zoro ', 'j.', 'jr.'],
#  ['boner', 'richard ', 'd.'],
#  ['stephens', 'donald ', 'w.'],
#  ['craig', 'john ', 'o.', 'iii'],
#  ['collier', 'christopher ', 'm.'],
#  ['stephens', 'ronald ', 'l.'],
#  ...]

# %%
judges_short = [' '.join(i[:2]).strip(" ") for i in judges] #updated to use 'judges' list instead of 'judges_clean'

# %%
from collections import Counter
judges_sorted = sorted(judges_short)
Counter(judges_sorted)
# Out:
# Counter({'abernathy g.': 2,
#          'abernethy richard': 2,
#          'adams gale': 3,
#          'adkins karl': 2,
#          'albright': 1,
#          'albright r.': 12,
#          'albright robert': 1,
#          'albright stuart': 6,
#          'albright w.': 18,
#          'aldridge thomas': 1,
#          'alexander karen': 1,
#          'alford benjamin': 24,
#          'allen j.': 18,
#          'allen philip': 1,
#          'allen stanley': 1,
#          'allen w.': 1,
#          'allsbrook richard': 3,
#          'ammons james': 10,
#          'anderson charles': 1,
#          'arguments panel': 1,
#          'baddour allen': 5,
#          'baddour r.': 6,
#          'baddour richard': 1,
#          'baker james': 14,
#          'balog steve': 12,
#          'balog steven': 1,
#          'banks j.': 1,
#          'barber wade': 7,
#          'barefoot napoleon': 1,
#          'barnette henry': 12,
#          'barrett sharon': 4,
#          'battle f.': 1,
#          'bawtinhimer stacey': 1,
#          'beal': 1,
#          'beal beverly': 12,
#          'beale michael': 16,
#          'beaman grafton': 1,
#          'bean c.': 3,
#          'bedsworth george': 2,
#          'bell j.': 1,
#          'bell james': 4,
#          'bell lisa': 13,
#          'bell w.': 11,
#          'best kimberly': 1,
#          'blackmore rebecca': 1,
#          'blake aretha': 1,
#          'bland william': 1,
#          'bledsoe louis': 3,
#          'blick joseph': 1,
#          'blount marvin': 7,
#          'bogle ronald': 1,
#          'boner richard': 31,
#          'bowen wiley': 16,
#          'bowers john': 1,
#          'brady robert': 1,
#          'bragg christopher': 3,
#          'brannon anthony': 1,
#          'brantley david': 1,
#          'braswell b.': 1,
#          'bray susan': 10,
#          'brewer coy': 1,
#          'bridges donald': 1,
#          'bridges f.': 1,
#          'bridges forrest': 25,
#          'bridges kevin': 5,
#          'bridges laura': 8,
#          'brooks selina': 1,
#          'brooks william': 1,
#          'brown anthony': 1,
#          'brown craig': 3,
#          'brown deborah': 2,
#          'brown frank': 3,
#          'brown richard': 4,
#          'brown shirley': 2,
#          'bryant steven': 1,
#          'bullock stafford': 7,
#          'burch susan': 1,
#          'burke l.': 20,
#          'burroughs robert': 1,
#          'bushfan elaine': 1,
#          'butterfield g.': 3,
#          'caldwell jesse': 19,
#          'cameron william': 2,
#          'campbell hugh': 1,
#          'carolina the': 7,
#          'carter clarence': 3,
#          'cashwell': 2,
#          'cashwell narley': 20,
#          'caudill gentry': 1,
#          'caudill j.': 6,
#          'caviness': 1,
#          'caviness loto': 9,
#          'cayer david': 9,
#          'cella eugene': 1,
#          'chapman ronald': 1,
#          'cilley robert': 1,
#          'clark giles': 1,
#          'cobb': 1,
#          'cobb w.': 42,
#          'cole j.': 9,
#          'collier christopher': 19,
#          'collins g.': 9,
#          'collins george': 3,
#          'conrad adam': 2,
#          'constangy h.': 3,
#          'cooper pell': 1,
#          'corbett a.': 1,
#          'corbett albert': 5,
#          'cornelius c.': 4,
#          'cornelius preston': 3,
#          'corpening j.': 1,
#          'court the': 1,
#          'covington mary': 1,
#          'coward william': 4,
#          'craig john': 33,
#          'cranford dwight': 4,
#          'cromer anderson': 20,
#          'cromer andy': 5,
#          'croom craig': 1,
#          'crosswhite joseph': 6,
#          'crow kenneth': 6,
#          'daisy william': 1,
#          'dameron e.': 3,
#          'davis amber': 3,
#          'davis chester': 3,
#          'davis danny': 1,
#          'davis j.': 6,
#          'davis james': 3,
#          'davis lindsay': 21,
#          'davis richard': 1,
#          'davis tommy': 2,
#          'dellinger j.': 1,
#          'deramus': 1,
#          'deramus judson': 10,
#          'desvousges shelley': 2,
#          'diaz albert': 9,
#          'doughton': 1,
#          'doughton richard': 28,
#          'downs': 1,
#          'downs james': 19,
#          'duke w.': 22,
#          'duncan michael': 1,
#          'eagles catherine': 30,
#          'eagles margaret': 1,
#          'edwards c.': 1,
#          'ellis b.': 7,
#          'ellis craig': 1,
#          'ennis spencer': 1,
#          'entzminger daniel': 1,
#          'ervin robert': 18,
#          'etheridge scott': 1,
#          'evans pat': 1,
#          'evans robert': 2,
#          'evans yvonne': 16,
#          'everett clifton': 8,
#          'fairley william': 1,
#          'faison james': 5,
#          'farmer robert': 2,
#          'ferrell forrest': 3,
#          'finch daniel': 1,
#          'fitch milton': 6,
#          'floyd r.': 1,
#          'floyd robert': 10,
#          'ford larry': 13,
#          'foster anna': 1,
#          'foster jefferey': 1,
#          'foster jeffrey': 1,
#          'foster thomas': 4,
#          'foust linwood': 4,
#          'fox carl': 21,
#          'foy louis': 1,
#          'freeman william': 6,
#          'frye henry': 5,
#          'fullwood ernest': 8,
#          'fullwood james': 2,
#          'futrell stephan': 1,
#          'g howard': 1,
#          'gale james': 11,
#          'galloway mark': 1,
#          'gardner john': 2,
#          'gavenus gary': 8,
#          'gavin lee': 1,
#          'gaylor charles': 1,
#          'gentry mike': 1,
#          'gessner paul': 17,
#          'gilchrist c.': 3,
#          'ginn c.': 7,
#          'ginn charles': 1,
#          'godwin walter': 8,
#          'gordon nancy': 1,
#          'gore': 1,
#          'gore william': 7,
#          'gorham phyllis': 15,
#          'gottlieb richard': 4,
#          'graham': 1,
#          'graham william': 1,
#          'grant cy': 5,
#          'gray beecher': 5,
#          'gray jane': 4,
#          'gray marvin': 12,
#          'greeson howard': 5,
#          'gregory edgar': 8,
#          'gregory keith': 2,
#          'griffin william': 16,
#          'grimes samuel': 2,
#          'gryder rebecca': 1,
#          'guice zoro': 12,
#          'haigwood thomas': 9,
#          'hall david': 1,
#          'hamby william': 1,
#          'hardin james': 11,
#          'harper jane': 1,
#          'harrell r.': 5,
#          'harrison hal': 1,
#          'harriss meader': 1,
#          'hartsfield denise': 1,
#          'hassell a.': 6,
#          'hassell andrew': 1,
#          'heath andrew': 2,
#          'heath elizabeth': 1,
#          'hedrick edward': 2,
#          'height henry': 1,
#          'helms michael': 19,
#          'helms william': 2,
#          'henry charles': 14,
#          'herring d.': 1,
#          'hight': 1,
#          'hight henry': 30,
#          'hill claire': 2,
#          'hill evelyn': 11,
#          'hill james': 3,
#          'hill kendra': 1,
#          'hinnant patrice': 8,
#          'hinton alma': 9,
#          'hobgood': 1,
#          'hobgood robert': 16,
#          'hockenbury jay': 10,
#          'hodges robert': 2,
#          'holshouser john': 3,
#          'holt rebecca': 1,
#          'holt shelly': 3,
#          'hooks d.': 13,
#          'hooks dewey': 1,
#          'hoover donnie': 1,
#          'horne gregory': 1,
#          'horne r.': 6,
#          'horton clarence': 6,
#          'houston jeanie': 2,
#          'hudson orlando': 54,
#          'hughes f.': 1,
#          'hunt jeff': 1,
#          'hyatt j.': 9,
#          'hyatt marlene': 2,
#          'iii james': 1,
#          'inman lucy': 10,
#          'jarrell h.': 1,
#          'jenkins jack': 13,
#          'jenkins knox': 18,
#          'john joseph': 5,
#          'johnson e.': 12,
#          'johnson marcus': 7,
#          'johnson robert': 2,
#          'johnston': 1,
#          'johnston robert': 28,
#          'jolly jerry': 2,
#          'jolly john': 17,
#          'jones abraham': 17,
#          'jones arnold': 9,
#          'jones paul': 14,
#          'jones william': 1,
#          'jordan lillian': 1,
#          'joseph shannon': 14,
#          'judgment granting': 3,
#          'keever a.': 2,
#          'key spencer': 2,
#          'kincaid timothy': 24,
#          'klass mark': 20,
#          'knight peter': 2,
#          'knox michael': 1,
#          'kuehnert daniel': 3,
#          'kwasikpui alfred': 1,
#          'l lisa': 1,
#          'labarre david': 9,
#          'lambeth d.': 1,
#          'lambeth david': 1,
#          'lamm charles': 9,
#          'lanier franklin': 2,
#          'lanier russell': 17,
#          'lanning james': 7,
#          'lassiter melissa': 3,
#          'lawton william': 1,
#          'leake larry': 1,
#          'leavell william': 2,
#          'lee jacquelyn': 4,
#          'lee w.': 12,
#          'letts bradley': 12,
#          'levinson eric': 5,
#          'lewis hugh': 10,
#          'lewis john': 1,
#          'lewis ola': 18,
#          'lewis robert': 2,
#          'lewis w.': 1,
#          'llewellyn james': 2,
#          'lock thomas': 9,
#          'locklear gary': 4,
#          'long lunsford': 1,
#          'long v.': 5,
#          'long vance': 4,
#          'love jimmy': 1,
#          'm craig': 1,
#          'maness jayrene': 1,
#          'mangum ned': 2,
#          'manning howard': 48,
#          'martin jerry': 6,
#          'martin lester': 2,
#          'massey a.': 5,
#          'massey moses': 1,
#          'may j.': 1,
#          'mccormick edward': 1,
#          'mccoy h.': 1,
#          'mcgee martin': 2,
#          'mcguire gregory': 3,
#          'mchugh peter': 11,
#          'mckeller c.': 1,
#          'mckown ann': 1,
#          'mclean mitchell': 2,
#          'mcswain lawrence': 1,
#          'mcthenia paige': 1,
#          'miller gordon': 2,
#          'miller regan': 1,
#          'mills l.': 1,
#          'morelock fred': 1,
#          'morey marcia': 2,
#          'morgan eric': 5,
#          'morgan james': 8,
#          'morgan melzer': 10,
#          'morgan michael': 13,
#          'morton j.': 1,
#          'mullinax robert': 1,
#          'murphy calvin': 3,
#          'myers jimmy': 1,
#          'n cressie': 1,
#          'n nancy': 1,
#          'nance commissioner': 1,
#          'noble l.': 2,
#          'noble lucy': 1,
#          'noble oliver': 1,
#          'nobles john': 11,
#          'norelli nancy': 1,
#          'ofoghludha michael': 2,
#          'oneal elaine': 1,
#          'orders walter': 1,
#          'osman matthew': 1,
#          'overby donald': 2,
#          'parker j.': 16,
#          'parker regina': 2,
#          'parker richard': 1,
#          'parsons w.': 3,
#          'patti': 1,
#          'patti timothy': 16,
#          'payne ronald': 22,
#          'penry j.': 1,
#          'phillips herbert': 2,
#          'pittman william': 2,
#          'pomeroy w.': 1,
#          'pool c.': 1,
#          'poovey nathaniel': 10,
#          'pope marvin': 9,
#          'powell mark': 20,
#          'quinn paul': 4,
#          'r allen': 2,
#          'r wade': 2,
#          'rader robert': 5,
#          'ragan james': 7,
#          'rand ripley': 16,
#          'reviewable and': 1,
#          'ridgeway paul': 15,
#          'roberson james': 3,
#          'robinson michael': 3,
#          'roda peter': 1,
#          'roemer victoria': 1,
#          'ross thomas': 1,
#          'rousseau julius': 4,
#          'royster ted': 1,
#          'royster theodore': 5,
#          'ruled ronald': 1,
#          's james': 1,
#          'salisbury anne': 1,
#          'sasser debra': 2,
#          'sasser douglas': 2,
#          'saunders chase': 3,
#          'scarlett beverly': 3,
#          'scott ward': 1,
#          'seaton sarah': 1,
#          'seay thomas': 1,
#          'sermons wayland': 5,
#          'sharpe margaret': 1,
#          'shirley a.': 9,
#          'sitton claude': 7,
#          'smith donald': 1,
#          'smith john': 1,
#          'smith osmond': 1,
#          'smith sean': 1,
#          'smith timothy': 1,
#          'smith w.': 23,
#          'southern william': 1,
#          'spainhour w.': 30,
#          'spencer': 1,
#          'spencer cheryl': 2,
#          'spencer james': 10,
#          'spivey ronald': 14,
#          'stanback a.': 15,
#          'stanback leon': 2,
#          'staton kimberly': 1,
#          'steelman sanford': 10,
#          'stephens donald': 41,
#          'stephens ronald': 11,
#          'stewart caron': 1,
#          'stiehl robert': 1,
#          'stone richard': 6,
#          'strickland david': 1,
#          'strickland james': 2,
#          'stubbs alice': 2,
#          'sturges cindy': 1,
#          'sumner quentin': 21,
#          'sumner robert': 3,
#          'sutton david': 1,
#          't entering': 1,
#          'tally mary': 3,
#          'taylor kim': 1,
#          'taylor kimberly': 9,
#          'taylor susan': 2,
#          'tennille ben': 19,
#          'thalheimer ben': 2,
#          'that to': 1,
#          'thigpen cressie': 2,
#          'thompson carolyn': 1,
#          'thompson jack': 14,
#          'thornburg alan': 12,
#          'tilghman carl': 7,
#          'tillery bradford': 1,
#          'tillet jerry': 1,
#          'tillett jerry': 8,
#          'titus kenneth': 18,
#          'trawick gary': 21,
#          'trivette robert': 1,
#          'trosch elizabeth': 1,
#          'trosch louis': 2,
#          'tucker kimbrell': 2,
#          'turner joseph': 2,
#          'turner r.': 1,
#          'vosburg james': 1,
#          'vosburgh james': 3,
#          'waddell jerry': 1,
#          'wagoner anna': 1,
#          'wainwright george': 1,
#          'walczyk christine': 2,
#          'walker richard': 1,
#          'walker russell': 15,
#          'wallace tanya': 7,
#          'ward j.': 1,
#          'warren raymond': 3,
#          'warren steve': 1,
#          'warren steven': 1,
#          'watson ebern': 3,
#          'webb james': 15,
#          'weeks gregory': 12,
#          'wiggins lamont': 1,
#          'wijewickrama roy': 1,
#          'wilhelm christy': 1,
#          'willey joshua': 1,
#          'williams joseph': 1,
#          'williams karen': 2,
#          'williamson f.': 8,
#          'wilson edwin': 9,
#          'winner dennis': 25,
#          'wood william': 13,
#          'you will': 1,
#          'z albert': 1,
#          'zimmerman h.': 3})

# %%
judges_short[0]
# Out:
# 'williams karen'

# %%
df.Trial_Judge = pd.Series(judges_short)

# %%
df.head()
# Out:
#                                              Opinion  SCT  Year_Filed File_Numbers    Result  \
# 0   an unpublished opinion of the north carolina ...    0        2020       19-563  affirmed
# 1  no. coa11-246 north carolina court of appeals ...    0        2012       11-246  affirmed
# 2  no. coa08-347 north carolina court of appeals ...    0        2009       08-347  affirmed
# 3  michael harrison gregory and wife, vivian greg...    0        2006       05-885  affirmed
# 4   in the court of appeals of north carolina no....    0        2017       17-112  reversed
#
#       Case_Type Case_Type_Confidence       Trial_Judge
# 0      property               84.62%    williams karen
# 1    employment               55.26%       hight henry
# 2      property               85.71%  poovey nathaniel
# 3     car_crash               33.33%      gore william
# 4  governmental               100.0%   stephens donald

# %% [markdown]
# #### Misc. Fix

# %%
df.Trial_Judge = df.Trial_Judge.map(lambda x: str(x))
trial_judge_errors = df[df['Trial_Judge'].str.contains('judgment', regex=False)]
judge_drop_list = list(trial_judge_errors.index)

# %%
judge_drop_list
# Out:
# [263, 1961, 2405]

# %%
df.drop(judge_drop_list, axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 6. Extract Feature: County

# %%
def extract_county(text):
    try:
        try:
            county = re.search("in (\w+) county",text[:4000])
            return county.group(1)
        except:
            county = re.search("(\w+) county", text)
            return county.group(1)
    except:
        return(None)

# %%
z = extract_county(df.Opinion[11])
print(z)
# Out:
# bladen

# %%
county_list = []
for i in range(len(df)):
    x = extract_county(df.Opinion[i])
    county_list.append(x)
    
df["County"] = pd.Series(county_list).values

# %%
df.County = df.County.fillna(value='-',)
counties_err = df.loc[df["County"] == '-']
counties_err.head(10)
# Out:
#                                                 Opinion  SCT  Year_Filed File_Numbers    Result  \
# 928    in the court of appeals of north carolina no....    0        2018       17-618  affirmed
# 938    in the court of appeals of north carolina no....    0        2018      17-1139  affirmed
# 1022  an unpublished opinion of the north carolina c...    0        2008       07-894  affirmed
# 1754  in the court of appeals of north carolina no. ...    0        2016      15-1300  reversed
# 1932   an unpublished opinion of the north carolina ...    0        2019       18-276  affirmed
# 2173   in the court of appeals of north carolina no....    0        2020        19-13  affirmed
# 2402  the presbyterian hospital, petitioner v. n.c. ...    0        2006       05-905  affirmed
# 2645   an unpublished opinion of the north carolina ...    0        2019       18-586  affirmed
#
#          Case_Type Case_Type_Confidence       Trial_Judge County
# 928     employment                60.0%  lassiter melissa      -
# 938       contract               33.33%    hobgood robert      -
# 1022     car_crash                50.0%    sasser douglas      -
# 1754    employment               100.0%    hudson orlando      -
# 1932    employment               100.0%      gessner paul      -
# 2173    employment               100.0%          ellis b.      -
# 2402  governmental               100.0%    caldwell jesse      -
# 2645  governmental               100.0%     foust linwood      -

# %%
# Drop 8 rows not returning any county
x = df.loc[df["County"] == '-']
y = x.index.tolist()
df.drop(y,inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Noted judge incorrectly noted as "judgment", only two outliers have this.

# %% [markdown]
# ## 8. One-Hot Encode Labels

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 9 columns):
# Opinion                 2665 non-null object
# SCT                     2665 non-null int64
# Year_Filed              2665 non-null int64
# File_Numbers            2665 non-null object
# Result                  2665 non-null object
# Case_Type               2665 non-null object
# Case_Type_Confidence    2665 non-null object
# Trial_Judge             2665 non-null object
# County                  2665 non-null object
# dtypes: int64(2), object(7)
# memory usage: 187.5+ KB

# %%
df.Result.replace('affirmed', 1, inplace=True)
df.Result.replace('reversed', 0, inplace=True)

# %%
df.describe()
# Out:
#           SCT  Year_Filed       Result
# count  2665.0  2665.00000  2665.000000
# mean      0.0  2008.39212     0.744465
# std       0.0     5.91212     0.436243
# min       0.0  1998.00000     0.000000
# 25%       0.0  2004.00000     0.000000
# 50%       0.0  2008.00000     1.000000
# 75%       0.0  2013.00000     1.000000
# max       0.0  2020.00000     1.000000

# %% [markdown]
# ## 8. EDA Visualizations

# %% [markdown]
# ### A. MSJ Allowed/Reversed Over Time

# %%
#Prepare visualizing delay by departure window
s1 = df.groupby(['Year_Filed'])['Result'].sum()
s2 = df.groupby(['Year_Filed'])['Result'].count()
df_affirmed = pd.concat([s1, s2], axis = 1)
df_affirmed.columns = ['Affirmed','Total']
df_affirmed['percent_affirmed'] = df_affirmed.Affirmed / df_affirmed.Total
df_affirmed['percent_reversed'] = 1- df_affirmed.percent_affirmed
df_affirmed.reset_index(inplace=True)

# %%
# Visualize On-Time Departures by the Departure Window
r = [x for x in range(1998,2021)]
greenBars = df_affirmed.percent_affirmed
redBars = df_affirmed.percent_reversed
barWidth = 0.85
names = r
# Create green Bars
plt.figure(figsize=(18,8))
plt.bar(r, greenBars, color='#69CB67', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, redBars, bottom=greenBars, color='#EE6666', edgecolor='white', width=barWidth)
plt.xticks(r, names)
plt.ylabel("Percent Affirmed (Green) and Reversed (Red) \n (Note truncated axis)")
plt.xlabel("Year Opinion Filed")
plt.title("Percentage of Affirmed vs. Reversed Motions by Year \n [Affirmed=Green, Reversed=Red]")

ax = plt.gca()
ax.set_ylim(0.4, ax.get_ylim()[1])

for i in range(len(r)):
  plt.annotate(round(df_affirmed.percent_affirmed[i]*100,1), 
               xy=(r[i]-.29,(df_affirmed.percent_affirmed[i] - 0.035)), color='black')
  plt.annotate(round(df_affirmed.percent_reversed[i]*100,1), 
               xy=(r[i]-.29,(df_affirmed.percent_affirmed[i] + 0.02)), color='black')

plt.show()

# %% [markdown]
# The cases generally favor affirming trial-court decisions, with only between 17.9% (2014) and 36.3% (1999) of trial-court decisions being reversed over the twenty-two year look-back period. There is no obvious pattern over the corpus' time frame, which is **reassuring** for our model, that time does not appear to play a significant role.

# %% [markdown]
# ### B. Corpus by Percentage of Case Type

# %%
#Horizontal bar chart
t1 = df.groupby(['Case_Type'])['Result'].sum()
t2 = df.groupby(['Case_Type'])['Result'].count()
df_casetype = pd.concat([t1, t2], axis = 1)
df_casetype.columns = ['Affirmed','Total']
df_casetype['percent_affirmed'] = df_casetype.Affirmed / df_casetype.Total
df_casetype.reset_index(inplace=True)

# %%
df_casetype.sort_values(by=['percent_affirmed'], ascending=False, inplace=True)
df_casetype.reset_index(inplace=True, drop=True)

# %%
f, ax = plt.subplots(figsize=(12,10))
sns.set_palette("hls", n_colors=25)
sns.barplot(x=df_casetype.percent_affirmed, y=df_casetype.Case_Type)
# sns.set_color_codes("hls", 8)
ax.set(ylabel="Case Type",
       xlabel="Percent Affirmed",
       title="Percentage of Affirmed Motions by Case Type")
for i in range(len(df_casetype)):
    anno = 'n affirmed = ' + str(df_casetype.Affirmed[i]) + ' out of ' + str(df_casetype.Total[i]) + ' (' + str(round(df_casetype.percent_affirmed[i]*100,2)) + '%)'
    plt.annotate(anno, 
               xy=(.02, i+.1), color='white', weight='bold')
plt.show()

# %% [markdown]
# While most cases are affirmed regardless of case type, this chart illustrates the relative likelihood of a given case type to be affirmed following a summary judgment motion, as compared to the other case types. The sample sizes of each type shown on the chart also illustrate the sample sizes, which give insight into the reliability of each case type's percentage.

# %% [markdown]
# ### C. Percent Granted by Case Type and Year

# %% [markdown]
# Scuttled -- Final plot was an incomprehensible mess since there were so many variations between 0-1.0 and so many case types.

# %% [markdown]
# ### D. Trial Judge

# %%
z1 = df.groupby(['Trial_Judge'])['Result'].sum()
z2 = df.groupby(['Trial_Judge'])['Result'].count()
df_judge = pd.concat([z1, z2], axis = 1)
df_judge.columns = ['Affirmed','Total']
df_judge['percent_affirmed'] = df_judge.Affirmed / df_judge.Total
df_judge.reset_index(inplace=True)

# %%
df_judge.sort_values(by=['Total'], ascending=False, inplace=True)
df_judge.reset_index(inplace=True, drop=True)

# %%
df_judge = df_judge[:20]

# %%
def judge_name(list_):
    string_ = list_.strip('[]').replace('\'','')
    return string_.title()

# %%
df_judge.Trial_Judge = df_judge.Trial_Judge.apply(lambda x: judge_name(x))

# %%
df_judge.sort_values(by=['percent_affirmed'], ascending=False, inplace=True)
df_judge.reset_index(inplace=True, drop=True)

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.set_palette("hls", n_colors=21)
sns.barplot(x=df_judge.percent_affirmed[:15], y=df_judge.Trial_Judge[:15])
ax.set(ylabel="Judges (Current and Former)",
       xlabel="Percent Affirmed",
       title="Top Ten Judges with Most Summary Judgment Cases Before the Court of Appeals* \n Organized by Percentage of Affirmed Cases (*after this model's filters were applied)")

for i in range(len(df_casetype)):
    anno = 'n affirmed: ' + str(df_judge.Affirmed[i]) + ' out of ' + str(df_judge.Total[i]) + ' (' + str(round(df_judge.percent_affirmed[i]*100,2)) + '%)'
    plt.annotate(anno, 
               xy=(.02, i+.1), color='white', weight='bold')
plt.show()

# %% [markdown]
# ## 9. Export Final DataFrame

# %%
# Save the new DF to a data file
with open('ProjectData/df_features.data', 'wb') as filehandle:
    # store the data as binary data stream
    pickle.dump(df, filehandle)
